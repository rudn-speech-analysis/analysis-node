# %%
import torch

# %%
if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
    for i in range(num_gpus):
        gpu_name = torch.cuda.get_device_name(i)
        print(f"GPU {i}: {gpu_name}")
else:
    print("CUDA is not available.")
# Out:
# GPU 0: AMD Radeon RX 9070 XT
# GPU 1: AMD Ryzen 7 7800X3D 8-Core Processor

# %%
DEVICE="cuda:0"

# %%
DATASET_DIR = "../dataset/audio"

ORIG_FILE = "./output/original.wav"
SPEAKER1_FILE = "./output/speaker1.wav"
SPEAKER2_FILE = "./output/speaker2.wav"
SPEAKER1_METRICS_FILE = "./output/speaker1.json"
SPEAKER2_METRICS_FILE = "./output/speaker2.json"

SPEAKER1_DIR = "./output/speaker1"
SPEAKER2_DIR = "./output/speaker2"

MIN_SEGMENT_LENGTH_SEC = 0.1
STOP_PHRASES = [
    "ДИНАМИЧНАЯ МУЗЫКА",
    "Продолжение следует.",
    "Продолжение следует...",
]
STOP_PHRASE_LENGTH_DELTA = 5

# %%
PER_SEGMENT_PROCESSORS = dict()
PER_CHANNEL_PROCESSORS = dict()

# %%
import os

os.makedirs(SPEAKER1_DIR, exist_ok=True)
os.makedirs(SPEAKER2_DIR, exist_ok=True)

# %%
import random

input_file = random.choice([
    f for f in os.listdir(DATASET_DIR)
    if os.path.isfile(os.path.join(DATASET_DIR, f))
])
input_file = f"{DATASET_DIR}/" + input_file
input_file
# Out:
# '../dataset/mix_13013_13136__2025_10_01__10_04_11_690.mp3'

# %%
import librosa
import soundfile as sf

y, sr = librosa.load(input_file, sr=None, mono=False)

if y.ndim != 2 or y.shape[0] != 2:
    raise ValueError("Input audio file must be stereo.")

sf.write(SPEAKER1_FILE, y[0], sr, subtype="PCM_16")
sf.write(SPEAKER2_FILE, y[1], sr, subtype="PCM_16")
sf.write(ORIG_FILE, y.T, sr, subtype="PCM_16")

# %%
import whisper
whispermodel = whisper.load_model("large").to(DEVICE)

# %%
from typing import Generator, Tuple

def filter_out(segment_data: dict) -> bool:
    # Removing short segments
    if (segment_data["end"] - segment_data["start"]) < MIN_SEGMENT_LENGTH_SEC:
        return True

    # Removing segments that contain stop_phrases
    matching_stop_phrases = [s for s in STOP_PHRASES if s.lower() in segment_data["text"].lower()]
    if matching_stop_phrases:
        # Remove the segment if it contains only a stop phrase
        if max(map(len, matching_stop_phrases)) + STOP_PHRASE_LENGTH_DELTA > len(segment_data["text"].strip()):
            return True
            
    return False

def segmentize(source: str, segments_dir: str) -> Generator[Tuple[dict, str]]:
    transcription = whispermodel.transcribe(source, word_timestamps=True, language='ru')
    y, sr = librosa.load(source, sr=None, mono=False)
    
    for segment_data in transcription['segments']:
        if filter_out(segment_data):
            continue
            
        start = float(segment_data['start'])
        end = float(segment_data['end'])
        start_sample = int(start * sr)
        end_sample = int(end * sr)

        segment_audio = y[:, start_sample:end_sample] if y.ndim == 2 else y[start_sample:end_sample]
        
        path = f"{segments_dir}/{segment_data['id']}.wav"
        sf.write(
            path,
            segment_audio.T if y.ndim == 2 else segment_audio,
            sr,
            subtype="PCM_16",
        )
        yield (segment_data, path)

# %%
def show(vals: dict) -> dict:
    keys = ["id", "start", "end", "text"]
    return {k: vals[0][k] for k in keys}
list(map(show, segmentize(SPEAKER1_FILE, SPEAKER1_DIR)))
# Out:
# [{'id': 0,
#   'start': np.float64(0.820000000000001),
#   'end': np.float64(4.24),
#   'text': ' Спасибо за ожидание. Компания «Автомир» в Аверно-Дмитровском шоссе.'},
#  {'id': 1,
#   'start': np.float64(4.32),
#   'end': np.float64(6.3),
#   'text': ' Оператор Татьяна, здравствуйте, Александр.'},
#  {'id': 2,
#   'start': np.float64(6.32),
#   'end': np.float64(8.98),
#   'text': ' На линии оставайтесь, пожалуйста. Съединю вас с менеджером.'},
#  {'id': 3,
#   'start': np.float64(9.06),
#   'end': np.float64(10.34),
#   'text': ' Александр, спасибо за звонок.'},
#  {'id': 5,
#   'start': np.float64(60.879999999999995),
#   'end': np.float64(65.18),
#   'text': ' Компания «Автомир», хавал-центр Дмитров, командер отдела продаж новых автомобилей «Барин Фан».'},
#  {'id': 6,
#   'start': np.float64(65.18),
#   'end': np.float64(68.24),
#   'text': ' Приветствую вас, Александр. У вас покупка нового автомобиля «Джулион» интересует.'},
#  {'id': 7,
#   'start': np.float64(72.76),
#   'end': np.float64(76.54),
#   'text': ' Понял вас. Ну, мы официальные дилеры, данные машины продаем, они у нас на лице есть.'},
#  {'id': 8,
#   'start': np.float64(76.62),
#   'end': np.float64(80.14),
#   'text': ' Продаем активно 25-й год. Вы насколько близко с машиной знакомы?'},
#  {'id': 9,
#   'start': np.float64(80.14),
#   'end': np.float64(83.12),
#   'text': ' Уже вы увидели, смотрели? Какую по комплектации предлагать?'},
#  {'id': 10,
#   'start': np.float64(88.44000000000001),
#   'end': np.float64(89.98),
#   'text': ' О, ага, здесь левая.'},
#  {'id': 11,
#   'start': np.float64(90.0),
#   'end': np.float64(95.08),
#   'text': ' Ну, смотрите, услуга тест-драйва бесплатная. Если уже выбираете машину, то лучше с машиной более детально ознакомиться,'},
#  {'id': 12,
#   'start': np.float64(95.12),
#   'end': np.float64(97.92),
#   'text': ' понимать, как она едет, какая трансмиссия, какая шумоизоляция.'},
#  {'id': 13,
#   'start': np.float64(97.98),
#   'end': np.float64(101.18),
#   'text': ' Услуга абсолютно бесплатная, можно без записи попробовать хоть сегодня.'},
#  {'id': 14,
#   'start': np.float64(102.24000000000001),
#   'end': np.float64(106.38),
#   'text': ' Вот. Александр, какие сроки рассматриваете покупку? Когда машина нужна?'},
#  {'id': 15,
#   'start': np.float64(107.2),
#   'end': np.float64(108.68),
#   'text': ' От этого зависит срона образования.'},
#  {'id': 16,
#   'start': np.float64(116.64),
#   'end': np.float64(119.98),
#   'text': ' Ну, смотрите, если через месяц, тогда то, что я вам сейчас скажу,'},
#  {'id': 17,
#   'start': np.float64(120.0),
#   'end': np.float64(122.22),
#   'text': ' оно абсолютно никакой силы иметь не будет.'},
#  {'id': 18,
#   'start': np.float64(122.3),
#   'end': np.float64(124.02),
#   'text': ' Потому что через месяц у нас будут другие условия.'},
#  {'id': 19,
#   'start': np.float64(124.08),
#   'end': np.float64(126.82),
#   'text': ' Мы продаем машины в режиме здесь и сейчас.'},
#  {'id': 20,
#   'start': np.float64(127.12),
#   'end': np.float64(130.96),
#   'text': ' Но сегодня могу вам условия какие-то организовать, если сегодня готовы приехать.'},
#  {'id': 21,
#   'start': np.float64(131.08),
#   'end': np.float64(134.48),
#   'text': ' Если через месяц, то приезжайте тогда через месяц, и будем уже вести разговор.'},
#  {'id': 22,
#   'start': np.float64(134.6),
#   'end': np.float64(137.72),
#   'text': ' Лучше через месяц просто другая цена уже будет.'},
#  {'id': 23,
#   'start': np.float64(138.02),
#   'end': np.float64(139.34),
#   'text': ' Интересный сбор меняется.'},
#  {'id': 24,
#   'start': np.float64(139.42),
#   'end': np.float64(142.8),
#   'text': ' Сейчас на подписание в государстве и уже другие цены.'},
#  {'id': 25,
#   'start': np.float64(142.8),
#   'end': np.float64(143.5),
#   'text': ' Сейчас даже дилеры.'},
#  {'id': 26,
#   'start': np.float64(144.22),
#   'end': np.float64(148.1),
#   'text': ' Ну, в нашей стране, конечно же, не только подешевение, а все только подорожание.'},
#  {'id': 27,
#   'start': np.float64(148.60000000000002),
#   'end': np.float64(149.98),
#   'text': ' Там на миллион изменения.'},
#  {'id': 28,
#   'start': np.float64(150.0),
#   'end': np.float64(152.14),
#   'text': ' Утилитационного сбора в средствах массовой информации.'},
#  {'id': 29,
#   'start': np.float64(152.22),
#   'end': 155.98,
#   'text': ' Посмотрите, в связи с этим дилеры уже меняют свою политику кардинальной.'},
#  {'id': 30,
#   'start': np.float64(156.68),
#   'end': np.float64(158.98),
#   'text': ' Ну, плавно, поступенчато повышаются цены.'},
#  {'id': 31,
#   'start': np.float64(158.98),
#   'end': np.float64(160.48),
#   'text': ' Сейчас машины сметают по счету раз.'},
#  {'id': 32,
#   'start': np.float64(160.86),
#   'end': np.float64(166.14),
#   'text': ' Поэтому, как бы, если через месяц это будет плюс там 500, плюс 300 тысяч рублей.'},
#  {'id': 33,
#   'start': np.float64(166.46),
#   'end': np.float64(168.2),
#   'text': ' Не знаю, насколько вам это будет актуально.'},
#  {'id': 34,
#   'start': np.float64(170.16),
#   'end': np.float64(171.5),
#   'text': ' Ну, на нет и суда нет.'},
#  {'id': 35,
#   'start': np.float64(172.20000000000002),
#   'end': np.float64(173.3),
#   'text': ' Тогда что говорит?'},
#  {'id': 36,
#   'start': np.float64(174.16),
#   'end': np.float64(174.6),
#   'text': ' Согласен.'},
#  {'id': 37,
#   'start': np.float64(174.68),
#   'end': np.float64(175.42),
#   'text': ' Тогда что говорит?'},
#  {'id': 38,
#   'start': np.float64(175.56),
#   'end': np.float64(176.9),
#   'text': ' В любом случае машина продается.'},
#  {'id': 39,
#   'start': np.float64(176.9),
#   'end': np.float64(179.36),
#   'text': ' Это какое-то имущество, какая-то собственность.'},
#  {'id': 40,
#   'start': np.float64(182.10000000000002),
#   'end': np.float64(182.46),
#   'text': ' Пожалуйста.'},
#  {'id': 41,
#   'start': np.float64(184.46),
#   'end': np.float64(185.42),
#   'text': ' Я вас понял.'},
#  {'id': 42,
#   'start': np.float64(185.54),
#   'end': np.float64(187.5),
#   'text': ' Все, Александр, сейчас, да, не могу говорить клиентам.'},
#  {'id': 43,
#   'start': np.float64(187.52),
#   'end': np.float64(188.5),
#   'text': ' Всего доброго за обращение.'},
#  {'id': 44,
#   'start': np.float64(188.5),
#   'end': np.float64(188.76),
#   'text': ' Спасибо.'},
#  {'id': 45,
#   'start': np.float64(189.06),
#   'end': np.float64(189.42),
#   'text': ' Успехов.'}]

# %%
from typing import Callable, Any
import pathlib
import dacite

from analysis_node.messages import MetricCollection
from analysis_node.analysis.postprocessing import WhisperMetrics
from analysis_node.analysis.processors import Processor

def collect_metrics_per_segment(
    segment_file: pathlib.Path | str,
) -> Tuple[dict[str, MetricCollection], dict[str, MetricCollection]]:
    def process(processors: dict[str, Processor]) -> dict[str, MetricCollection]:
        return {
            proc_name: processor.process(segment_file)
            for proc_name, processor in processors.items()
        }

    return (
        process(PER_SEGMENT_PROCESSORS),
        process(PER_CHANNEL_PROCESSORS),
    )

def collect_metrics_per_channel(
    channel_file: pathlib.Path | str,
    segments_dir: pathlib.Path | str,
) -> Generator[
    Tuple[dict[str, MetricCollection], dict[str, MetricCollection], WhisperMetrics],
    None,
    None,
]:
    for segment_data, segment_path in segmentize(channel_file, segments_dir):
        per_segment, per_channel = collect_metrics_per_segment(segment_path)
        whisper_data = dacite.from_dict(
            data_class=WhisperMetrics,
            data=segment_data,
        )
        yield per_segment, per_channel, whisper_data
# Out:
# /home/gmatiukhin/.conda/envs/speech-analysis/lib/python3.13/site-packages/pyannote/audio/core/io.py:48: UserWarning:
# torchcodec is not installed correctly so built-in audio decoding will fail. Solutions are:
# * use audio preloaded in-memory as a {'waveform': (channel, time) torch.Tensor, 'sample_rate': int} dictionary;
# * fix torchcodec installation. Error message was:
#
# Deliberately disabling torchcodec.
#   warnings.warn(
# /home/gmatiukhin/.conda/envs/speech-analysis/lib/python3.13/site-packages/speechbrain/utils/torch_audio_backend.py:57: UserWarning: torchaudio._backend.list_audio_backends has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   available_backends = torchaudio.list_audio_backends()

# %%
from analysis_node.analysis.processors import VadEmotionProcessor
from analysis_node.analysis.processors import AgeGenderProcessor

PER_SEGMENT_PROCESSORS["emotion"] = VadEmotionProcessor(DEVICE)
PER_CHANNEL_PROCESSORS["age_gender"] = AgeGenderProcessor("small", DEVICE)

# %%
raw_metrics = list(collect_metrics_per_channel(SPEAKER1_FILE, SPEAKER1_DIR))
raw_metrics
# Out:
# [({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5853163599967957, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.595945417881012, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.38391968607902527, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=29, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.9996389150619507, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.00021282209490891546, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.00014820143405813724, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=0, seek=0, start=np.float64(0.820000000000001), end=np.float64(4.24), text=' Спасибо за ожидание. Компания «Автомир» в Аверно-Дмитровском шоссе.', tokens=[50409, 29219, 4396, 47136, 9633, 13, 3422, 1253, 1354, 8831, 4657, 5594, 859, 17804, 4490, 5933, 740, 3450, 10327, 1234, 12, 8442, 919, 1635, 6680, 29166, 5941, 15770, 387, 13, 50584], temperature=0.0, avg_logprob=-0.20426487922668457, compression_ratio=1.7264150943396226, no_speech_prob=0.23092328011989594, words=[WordMetrics(word=' Спасибо', start=np.float64(0.820000000000001), end=np.float64(1.36), probability=np.float64(0.9863502383232117)), WordMetrics(word=' за', start=np.float64(1.36), end=np.float64(1.58), probability=np.float64(0.9995991587638855)), WordMetrics(word=' ожидание.', start=np.float64(1.58), end=np.float64(2.02), probability=np.float64(0.982098400592804)), WordMetrics(word=' Компания', start=np.float64(2.06), end=np.float64(2.54), probability=np.float64(0.9996850788593292)), WordMetrics(word=' «Автомир»', start=np.float64(2.54), end=np.float64(2.94), probability=np.float64(0.8543831904729208)), WordMetrics(word=' в', start=np.float64(2.94), end=np.float64(3.14), probability=np.float64(0.208328977227211)), WordMetrics(word=' Аверно', start=np.float64(3.14), end=np.float64(3.4), probability=np.float64(0.6104585230350494)), WordMetrics(word='-Дмитровском', start=np.float64(3.4), end=np.float64(3.88), probability=np.float64(0.9921143551667532)), WordMetrics(word=' шоссе.', start=np.float64(3.88), end=np.float64(4.24), probability=np.float64(0.999242901802063))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5475844144821167, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5170494914054871, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.5999453067779541, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=27, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.9988816380500793, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=6.862966256448999e-05, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0010498036863282323, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=1, seek=0, start=np.float64(4.32), end=np.float64(6.3), text=' Оператор Татьяна, здравствуйте, Александр.', tokens=[50591, 45246, 13126, 2542, 3200, 2209, 681, 1931, 11, 7608, 36359, 11, 44938, 481, 13, 50682], temperature=0.0, avg_logprob=-0.20426487922668457, compression_ratio=1.7264150943396226, no_speech_prob=0.23092328011989594, words=[WordMetrics(word=' Оператор', start=np.float64(4.32), end=np.float64(4.86), probability=np.float64(0.9524350961049398)), WordMetrics(word=' Татьяна,', start=np.float64(4.86), end=np.float64(5.22), probability=np.float64(0.9963588863611221)), WordMetrics(word=' здравствуйте,', start=np.float64(5.3), end=np.float64(5.66), probability=np.float64(0.6629213988780975)), WordMetrics(word=' Александр.', start=np.float64(5.7), end=np.float64(6.3), probability=np.float64(0.9991263151168823))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5750419497489929, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5789816975593567, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.45264267921447754, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=31, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.9992733597755432, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.00043009594082832336, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0002965247258543968, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=2, seek=0, start=np.float64(6.32), end=np.float64(8.98), text=' На линии оставайтесь, пожалуйста. Съединю вас с менеджером.', tokens=[50697, 11245, 7444, 1903, 435, 25969, 30100, 11, 32518, 13, 2933, 8515, 30741, 1148, 10655, 776, 6046, 2229, 1820, 33370, 13, 50817], temperature=0.0, avg_logprob=-0.20426487922668457, compression_ratio=1.7264150943396226, no_speech_prob=0.23092328011989594, words=[WordMetrics(word=' На', start=np.float64(6.32), end=np.float64(6.74), probability=np.float64(0.9838623404502869)), WordMetrics(word=' линии', start=np.float64(6.74), end=np.float64(7.02), probability=np.float64(0.9954925576845804)), WordMetrics(word=' оставайтесь,', start=np.float64(7.02), end=np.float64(7.42), probability=np.float64(0.955039381980896)), WordMetrics(word=' пожалуйста.', start=np.float64(7.48), end=np.float64(7.74), probability=np.float64(0.9999867677688599)), WordMetrics(word=' Съединю', start=np.float64(7.98), end=np.float64(8.36), probability=np.float64(0.5795784182846546)), WordMetrics(word=' вас', start=np.float64(8.36), end=np.float64(8.48), probability=np.float64(0.9791783094406128)), WordMetrics(word=' с', start=np.float64(8.48), end=np.float64(8.6), probability=np.float64(0.9987150430679321)), WordMetrics(word=' менеджером.', start=np.float64(8.6), end=np.float64(8.98), probability=np.float64(0.9658534377813339))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5946773886680603, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5752196907997131, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.37682482600212097, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=33, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.999747097492218, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.00013336514530237764, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.00011948608153034002, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=3, seek=0, start=np.float64(9.06), end=np.float64(10.34), text=' Александр, спасибо за звонок.', tokens=[50825, 44938, 481, 11, 37536, 4396, 45832, 2637, 13, 50885], temperature=0.0, avg_logprob=-0.20426487922668457, compression_ratio=1.7264150943396226, no_speech_prob=0.23092328011989594, words=[WordMetrics(word=' Александр,', start=np.float64(9.06), end=np.float64(9.52), probability=np.float64(0.9997750520706177)), WordMetrics(word=' спасибо', start=np.float64(9.52), end=np.float64(9.72), probability=np.float64(0.9999890327453613)), WordMetrics(word=' за', start=np.float64(9.72), end=np.float64(9.98), probability=np.float64(0.999941349029541)), WordMetrics(word=' звонок.', start=np.float64(9.98), end=np.float64(10.34), probability=np.float64(0.9993923306465149))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5656676292419434, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5816912055015564, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.4393845200538635, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=35, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.0003303200064692646, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9992896318435669, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.000380070909159258, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=5, seek=6000, start=np.float64(60.879999999999995), end=np.float64(65.18), text=' Компания «Автомир», хавал-центр Дмитров, командер отдела продаж новых автомобилей «Барин Фан».', tokens=[50365, 3422, 1253, 1354, 8831, 4657, 5594, 859, 17804, 4490, 21606, 3490, 1828, 1218, 12, 1814, 5243, 481, 3401, 919, 1635, 6680, 11, 35991, 1135, 50176, 386, 11354, 3234, 46308, 37122, 2338, 2345, 4657, 18172, 2222, 2599, 13196, 1416, 12513, 50631], temperature=0.0, avg_logprob=-0.2072870700390308, compression_ratio=1.8676844783715012, no_speech_prob=0.01242966577410698, words=[WordMetrics(word=' Компания', start=np.float64(60.879999999999995), end=np.float64(61.4), probability=np.float64(0.929186150431633)), WordMetrics(word=' «Автомир»,', start=np.float64(61.4), end=np.float64(61.92), probability=np.float64(0.7876189003388087)), WordMetrics(word=' хавал', start=np.float64(61.92), end=np.float64(62.18), probability=np.float64(0.7933278679847717)), WordMetrics(word='-центр', start=np.float64(62.18), end=np.float64(62.5), probability=np.float64(0.9896190315485001)), WordMetrics(word=' Дмитров,', start=np.float64(62.5), end=np.float64(62.84), probability=np.float64(0.8774942755699158)), WordMetrics(word=' командер', start=np.float64(62.9), end=np.float64(63.26), probability=np.float64(0.48147002607584)), WordMetrics(word=' отдела', start=np.float64(63.26), end=np.float64(63.56), probability=np.float64(0.9805126190185547)), WordMetrics(word=' продаж', start=np.float64(63.56), end=np.float64(63.84), probability=np.float64(0.9934430122375488)), WordMetrics(word=' новых', start=np.float64(63.84), end=np.float64(63.98), probability=np.float64(0.997374415397644)), WordMetrics(word=' автомобилей', start=np.float64(63.98), end=np.float64(64.54), probability=np.float64(0.9996784925460815)), WordMetrics(word=' «Барин', start=np.float64(64.54), end=np.float64(64.8), probability=np.float64(0.9026707708835602)), WordMetrics(word=' Фан».', start=np.float64(64.8), end=np.float64(65.18), probability=np.float64(0.7372945447762808))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5723423957824707, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5816469192504883, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.558314323425293, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=38, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.0012622401118278503, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9982852339744568, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.00045255976147018373, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=6, seek=6000, start=np.float64(65.18), end=np.float64(68.24), text=' Приветствую вас, Александр. У вас покупка нового автомобиля «Джулион» интересует.', tokens=[50631, 38932, 2981, 3924, 10655, 11, 44938, 481, 13, 6523, 10655, 34005, 2833, 10022, 2350, 37122, 50211, 4657, 8442, 1820, 28646, 1784, 5933, 15033, 17781, 13, 50782], temperature=0.0, avg_logprob=-0.2072870700390308, compression_ratio=1.8676844783715012, no_speech_prob=0.01242966577410698, words=[WordMetrics(word=' Приветствую', start=np.float64(65.18), end=np.float64(65.74), probability=np.float64(0.9848450620969137)), WordMetrics(word=' вас,', start=np.float64(65.74), end=np.float64(65.88), probability=np.float64(0.9700407981872559)), WordMetrics(word=' Александр.', start=np.float64(65.9), end=np.float64(66.3), probability=np.float64(0.9976574182510376)), WordMetrics(word=' У', start=np.float64(66.34), end=np.float64(66.42), probability=np.float64(0.7374831438064575)), WordMetrics(word=' вас', start=np.float64(66.42), end=np.float64(66.48), probability=np.float64(0.7463560700416565)), WordMetrics(word=' покупка', start=np.float64(66.48), end=np.float64(66.88), probability=np.float64(0.9988579750061035)), WordMetrics(word=' нового', start=np.float64(66.88), end=np.float64(67.08), probability=np.float64(0.9980201125144958)), WordMetrics(word=' автомобиля', start=np.float64(67.08), end=np.float64(67.5), probability=np.float64(0.9999591708183289)), WordMetrics(word=' «Джулион»', start=np.float64(67.5), end=np.float64(67.84), probability=np.float64(0.8431325554847717)), WordMetrics(word=' интересует.', start=np.float64(67.84), end=np.float64(68.24), probability=np.float64(0.9848434329032898))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5706225633621216, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5708594918251038, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.3039717376232147, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=25, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=2.8179900255054235e-05, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.999729573726654, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.00024218627368099988, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=7, seek=6000, start=np.float64(72.76), end=np.float64(76.54), text=' Понял вас. Ну, мы официальные дилеры, данные машины продаем, они у нас на лице есть.', tokens=[51006, 36067, 16065, 10655, 13, 7571, 11, 4777, 31950, 30321, 25967, 1070, 2338, 24626, 11, 19582, 4970, 19820, 18835, 11354, 7906, 11, 7515, 1595, 6519, 1470, 7444, 15524, 5640, 13, 51197], temperature=0.0, avg_logprob=-0.2072870700390308, compression_ratio=1.8676844783715012, no_speech_prob=0.01242966577410698, words=[WordMetrics(word=' Понял', start=np.float64(72.76), end=np.float64(73.28), probability=np.float64(0.9560887515544891)), WordMetrics(word=' вас.', start=np.float64(73.28), end=np.float64(73.46), probability=np.float64(0.9807704091072083)), WordMetrics(word=' Ну,', start=np.float64(73.56), end=np.float64(73.64), probability=np.float64(0.8374003171920776)), WordMetrics(word=' мы', start=np.float64(73.68), end=np.float64(73.84), probability=np.float64(0.9998953342437744)), WordMetrics(word=' официальные', start=np.float64(73.84), end=np.float64(74.22), probability=np.float64(0.9959123730659485)), WordMetrics(word=' дилеры,', start=np.float64(74.22), end=np.float64(74.54), probability=np.float64(0.9993697802225748)), WordMetrics(word=' данные', start=np.float64(74.58), end=np.float64(74.94), probability=np.float64(0.9975196719169617)), WordMetrics(word=' машины', start=np.float64(74.94), end=np.float64(75.24), probability=np.float64(0.9998775720596313)), WordMetrics(word=' продаем,', start=np.float64(75.24), end=np.float64(75.6), probability=np.float64(0.9877969622612)), WordMetrics(word=' они', start=np.float64(75.66), end=np.float64(75.8), probability=np.float64(0.9994807839393616)), WordMetrics(word=' у', start=np.float64(75.8), end=np.float64(75.92), probability=np.float64(0.999976634979248)), WordMetrics(word=' нас', start=np.float64(75.92), end=np.float64(76.02), probability=np.float64(0.9995885491371155)), WordMetrics(word=' на', start=np.float64(76.02), end=np.float64(76.14), probability=np.float64(0.42655912041664124)), WordMetrics(word=' лице', start=np.float64(76.14), end=np.float64(76.36), probability=np.float64(0.9306953251361847)), WordMetrics(word=' есть.', start=np.float64(76.36), end=np.float64(76.54), probability=np.float64(0.9998212456703186))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5693902969360352, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5833086371421814, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.3305870592594147, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=21, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.00010884505900321528, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9956259727478027, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.004265207331627607, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=8, seek=6000, start=np.float64(76.62), end=np.float64(80.14), text=' Продаем активно 25-й год. Вы насколько близко с машиной знакомы?', tokens=[51205, 8567, 1435, 7906, 30239, 1234, 3552, 12, 1644, 9182, 13, 11886, 49635, 37060, 3752, 776, 19820, 30933, 40909, 698, 30, 51375], temperature=0.0, avg_logprob=-0.2072870700390308, compression_ratio=1.8676844783715012, no_speech_prob=0.01242966577410698, words=[WordMetrics(word=' Продаем', start=np.float64(76.62), end=np.float64(77.02), probability=np.float64(0.9974403778711954)), WordMetrics(word=' активно', start=np.float64(77.02), end=np.float64(77.42), probability=np.float64(0.9996612071990967)), WordMetrics(word=' 25', start=np.float64(77.42), end=np.float64(77.68), probability=np.float64(0.5263789296150208)), WordMetrics(word='-й', start=np.float64(77.68), end=np.float64(78.26), probability=np.float64(0.9962795078754425)), WordMetrics(word=' год.', start=np.float64(78.26), end=np.float64(78.4), probability=np.float64(0.9999791383743286)), WordMetrics(word=' Вы', start=np.float64(78.5), end=np.float64(78.66), probability=np.float64(0.9994345307350159)), WordMetrics(word=' насколько', start=np.float64(78.66), end=np.float64(78.92), probability=np.float64(0.9693384170532227)), WordMetrics(word=' близко', start=np.float64(78.92), end=np.float64(79.38), probability=np.float64(0.9998437464237213)), WordMetrics(word=' с', start=np.float64(79.38), end=np.float64(79.42), probability=np.float64(0.8392926454544067)), WordMetrics(word=' машиной', start=np.float64(79.42), end=np.float64(79.72), probability=np.float64(0.9847950041294098)), WordMetrics(word=' знакомы?', start=np.float64(79.72), end=np.float64(80.14), probability=np.float64(0.9996086359024048))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5901305675506592, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5994055271148682, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.5825881958007812, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=21, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=1.8318027059649467e-06, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.999420166015625, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0005780237261205912, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=9, seek=6000, start=np.float64(80.14), end=np.float64(83.12), text=' Уже вы увидели, смотрели? Какую по комплектации предлагать?', tokens=[51377, 6523, 4757, 2840, 21974, 8334, 11, 17726, 8334, 30, 11011, 3924, 2801, 14380, 21579, 16715, 46841, 2209, 30, 51524], temperature=0.0, avg_logprob=-0.2072870700390308, compression_ratio=1.8676844783715012, no_speech_prob=0.01242966577410698, words=[WordMetrics(word=' Уже', start=np.float64(80.14), end=np.float64(80.26), probability=np.float64(0.8274051547050476)), WordMetrics(word=' вы', start=np.float64(80.26), end=np.float64(80.38), probability=np.float64(0.7886720299720764)), WordMetrics(word=' увидели,', start=np.float64(80.38), end=np.float64(80.72), probability=np.float64(0.7932366728782654)), WordMetrics(word=' смотрели?', start=np.float64(80.72), end=np.float64(81.16), probability=np.float64(0.9995752573013306)), WordMetrics(word=' Какую', start=np.float64(81.56), end=np.float64(82.08), probability=np.float64(0.9781085252761841)), WordMetrics(word=' по', start=np.float64(82.08), end=np.float64(82.2), probability=np.float64(0.761780858039856)), WordMetrics(word=' комплектации', start=np.float64(82.2), end=np.float64(82.66), probability=np.float64(0.8152638574441274)), WordMetrics(word=' предлагать?', start=np.float64(82.66), end=np.float64(83.12), probability=np.float64(0.8664683997631073))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.3886444568634033, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.4232719838619232, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.4429168105125427, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=15, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=4.531650847638957e-05, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.995469331741333, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.004485391546040773, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=10, seek=6000, start=np.float64(88.44000000000001), end=np.float64(89.98), text=' О, ага, здесь левая.', tokens=[51783, 3688, 11, 2559, 18706, 11, 9087, 2344, 3515, 4251, 13, 51864], temperature=0.0, avg_logprob=-0.2072870700390308, compression_ratio=1.8676844783715012, no_speech_prob=0.01242966577410698, words=[WordMetrics(word=' О,', start=np.float64(88.44000000000001), end=np.float64(88.96000000000001), probability=np.float64(0.6915299296379089)), WordMetrics(word=' ага,', start=np.float64(88.96000000000001), end=np.float64(89.48), probability=np.float64(0.9399586915969849)), WordMetrics(word=' здесь', start=np.float64(89.5), end=np.float64(89.74), probability=np.float64(0.6977219581604004)), WordMetrics(word=' левая.', start=np.float64(89.74), end=np.float64(89.98), probability=np.float64(0.37820617854595184))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.6500287652015686, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.63795006275177, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.46562501788139343, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=26, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=1.2510939995991066e-05, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9996671676635742, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.00032034891773946583, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=11, seek=9000, start=np.float64(90.0), end=np.float64(95.08), text=' Ну, смотрите, услуга тест-драйва бесплатная. Если уже выбираете машину, то лучше с машиной более детально ознакомиться,', tokens=[50365, 7571, 11, 46441, 11, 24636, 585, 18706, 41699, 12, 856, 481, 3183, 20635, 32971, 25834, 6323, 13, 12412, 7520, 18061, 4490, 17670, 19820, 15387, 11, 4572, 21569, 776, 19820, 30933, 15103, 15079, 10986, 29176, 45051, 12306, 11, 50621], temperature=0.0, avg_logprob=-0.1512395151845225, compression_ratio=2.0474934036939314, no_speech_prob=0.024042272940278053, words=[WordMetrics(word=' Ну,', start=np.float64(90.0), end=np.float64(90.36), probability=np.float64(0.6842030882835388)), WordMetrics(word=' смотрите,', start=np.float64(90.42), end=np.float64(90.54), probability=np.float64(0.9966585636138916)), WordMetrics(word=' услуга', start=np.float64(90.64), end=np.float64(90.94), probability=np.float64(0.9992338220278422)), WordMetrics(word=' тест', start=np.float64(90.94), end=np.float64(91.12), probability=np.float64(0.5793039798736572)), WordMetrics(word='-драйва', start=np.float64(91.12), end=np.float64(91.34), probability=np.float64(0.9166948676109314)), WordMetrics(word=' бесплатная.', start=np.float64(91.34), end=np.float64(91.94), probability=np.float64(0.9015824993451437)), WordMetrics(word=' Если', start=np.float64(91.96), end=np.float64(92.1), probability=np.float64(0.9990240335464478)), WordMetrics(word=' уже', start=np.float64(92.1), end=np.float64(92.32), probability=np.float64(0.6415214538574219)), WordMetrics(word=' выбираете', start=np.float64(92.32), end=np.float64(92.82), probability=np.float64(0.9414913654327393)), WordMetrics(word=' машину,', start=np.float64(92.82), end=np.float64(93.26), probability=np.float64(0.9999476671218872)), WordMetrics(word=' то', start=np.float64(93.26), end=np.float64(93.38), probability=np.float64(0.9977420568466187)), WordMetrics(word=' лучше', start=np.float64(93.38), end=np.float64(93.54), probability=np.float64(0.9998958110809326)), WordMetrics(word=' с', start=np.float64(93.54), end=np.float64(93.68), probability=np.float64(0.9996733665466309)), WordMetrics(word=' машиной', start=np.float64(93.68), end=np.float64(94.0), probability=np.float64(0.9997637271881104)), WordMetrics(word=' более', start=np.float64(94.0), end=np.float64(94.2), probability=np.float64(0.9984349608421326)), WordMetrics(word=' детально', start=np.float64(94.2), end=np.float64(94.54), probability=np.float64(0.9999249577522278)), WordMetrics(word=' ознакомиться,', start=np.float64(94.54), end=np.float64(95.08), probability=np.float64(0.9953811168670654))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5195812582969666, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.541502058506012, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.3105185925960541, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=29, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=6.51365116937086e-05, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9994454979896545, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0004893454606644809, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=12, seek=9000, start=np.float64(95.12), end=np.float64(97.92), text=' понимать, как она едет, какая трансмиссия, какая шумоизоляция.', tokens=[50625, 15084, 2209, 11, 3014, 8826, 20686, 1094, 11, 29334, 7550, 15720, 919, 31632, 7409, 11, 29334, 5941, 5525, 354, 5572, 41332, 17651, 13, 50765], temperature=0.0, avg_logprob=-0.1512395151845225, compression_ratio=2.0474934036939314, no_speech_prob=0.024042272940278053, words=[WordMetrics(word=' понимать,', start=np.float64(95.12), end=np.float64(95.42), probability=np.float64(0.997417688369751)), WordMetrics(word=' как', start=np.float64(95.46), end=np.float64(95.58), probability=np.float64(0.9698689579963684)), WordMetrics(word=' она', start=np.float64(95.58), end=np.float64(95.74), probability=np.float64(0.9998987913131714)), WordMetrics(word=' едет,', start=np.float64(95.74), end=np.float64(96.14), probability=np.float64(0.9994319379329681)), WordMetrics(word=' какая', start=np.float64(96.14), end=np.float64(96.4), probability=np.float64(0.9998096823692322)), WordMetrics(word=' трансмиссия,', start=np.float64(96.4), end=np.float64(97.08), probability=np.float64(0.9994498729705811)), WordMetrics(word=' какая', start=np.float64(97.1), end=np.float64(97.28), probability=np.float64(0.9998315572738647)), WordMetrics(word=' шумоизоляция.', start=np.float64(97.28), end=np.float64(97.92), probability=np.float64(0.997138092915217))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.594653308391571, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.6377074122428894, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.23569892346858978, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=23, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=5.745312591898255e-05, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9992550015449524, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0006874738028272986, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=13, seek=9000, start=np.float64(97.98), end=np.float64(101.18), text=' Услуга абсолютно бесплатная, можно без записи попробовать хоть сегодня.', tokens=[50770, 6523, 14393, 585, 18706, 35060, 32971, 25834, 6323, 11, 8885, 10969, 36426, 435, 34089, 14069, 39605, 17413, 13, 50934], temperature=0.0, avg_logprob=-0.1512395151845225, compression_ratio=2.0474934036939314, no_speech_prob=0.024042272940278053, words=[WordMetrics(word=' Услуга', start=np.float64(97.98), end=np.float64(98.26), probability=np.float64(0.9915897399187088)), WordMetrics(word=' абсолютно', start=np.float64(98.26), end=np.float64(98.52), probability=np.float64(0.9998225569725037)), WordMetrics(word=' бесплатная,', start=np.float64(98.52), end=np.float64(99.16), probability=np.float64(0.989334245522817)), WordMetrics(word=' можно', start=np.float64(99.16), end=np.float64(99.28), probability=np.float64(0.9994797110557556)), WordMetrics(word=' без', start=np.float64(99.28), end=np.float64(99.5), probability=np.float64(0.9984153509140015)), WordMetrics(word=' записи', start=np.float64(99.5), end=np.float64(99.94), probability=np.float64(0.9997866749763489)), WordMetrics(word=' попробовать', start=np.float64(99.94), end=np.float64(100.78), probability=np.float64(0.9737451076507568)), WordMetrics(word=' хоть', start=np.float64(100.78), end=np.float64(100.9), probability=np.float64(0.9987817406654358)), WordMetrics(word=' сегодня.', start=np.float64(100.9), end=np.float64(101.18), probability=np.float64(0.9988798499107361))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.6305590271949768, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.632192850112915, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.6145579218864441, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=30, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.0002253657003166154, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9993183612823486, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.000456273730378598, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=14, seek=9000, start=np.float64(102.24000000000001), end=np.float64(106.38), text=' Вот. Александр, какие сроки рассматриваете покупку? Когда машина нужна?', tokens=[50990, 9756, 13, 44938, 481, 11, 19971, 776, 32948, 435, 23345, 34476, 481, 2739, 17670, 34005, 4401, 30, 23128, 19820, 7861, 9353, 1931, 30, 51190], temperature=0.0, avg_logprob=-0.1512395151845225, compression_ratio=2.0474934036939314, no_speech_prob=0.024042272940278053, words=[WordMetrics(word=' Вот.', start=np.float64(102.24000000000001), end=np.float64(102.68), probability=np.float64(0.5903846621513367)), WordMetrics(word=' Александр,', start=np.float64(103.5), end=np.float64(103.94), probability=np.float64(0.9980624914169312)), WordMetrics(word=' какие', start=np.float64(103.94), end=np.float64(104.12), probability=np.float64(0.5834072828292847)), WordMetrics(word=' сроки', start=np.float64(104.12), end=np.float64(104.58), probability=np.float64(0.9999730189641317)), WordMetrics(word=' рассматриваете', start=np.float64(104.58), end=np.float64(105.04), probability=np.float64(0.9654272556304931)), WordMetrics(word=' покупку?', start=np.float64(105.04), end=np.float64(105.52), probability=np.float64(0.9986284375190735)), WordMetrics(word=' Когда', start=np.float64(105.54), end=np.float64(105.88), probability=np.float64(0.9989686012268066)), WordMetrics(word=' машина', start=np.float64(105.88), end=np.float64(106.2), probability=np.float64(0.9654070138931274)), WordMetrics(word=' нужна?', start=np.float64(106.2), end=np.float64(106.38), probability=np.float64(0.9905498027801514))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.49682748317718506, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5301744341850281, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.43564772605895996, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=29, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.00012417894322425127, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9951213002204895, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.004754519090056419, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=15, seek=9000, start=np.float64(107.2), end=np.float64(108.68), text=' От этого зависит срона образования.', tokens=[51244, 18611, 10751, 39673, 1635, 776, 481, 14411, 17938, 30821, 13, 51305], temperature=0.0, avg_logprob=-0.1512395151845225, compression_ratio=2.0474934036939314, no_speech_prob=0.024042272940278053, words=[WordMetrics(word=' От', start=np.float64(107.2), end=np.float64(107.64), probability=np.float64(0.9910228252410889)), WordMetrics(word=' этого', start=np.float64(107.64), end=np.float64(107.82), probability=np.float64(0.999757707118988)), WordMetrics(word=' зависит', start=np.float64(107.82), end=np.float64(108.18), probability=np.float64(0.9985573887825012)), WordMetrics(word=' срона', start=np.float64(108.18), end=np.float64(108.28), probability=np.float64(0.2494525114695231)), WordMetrics(word=' образования.', start=np.float64(108.28), end=np.float64(108.68), probability=np.float64(0.9990609288215637))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.627703070640564, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.6055677533149719, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.25887158513069153, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=33, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.00017206204938702285, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9996362924575806, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0001916796318255365, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=16, seek=9000, start=np.float64(116.64), end=np.float64(119.98), text=' Ну, смотрите, если через месяц, тогда то, что я вам сейчас скажу,', tokens=[51698, 7571, 11, 46441, 11, 8042, 17341, 29329, 1814, 11, 21696, 4572, 11, 2143, 2552, 10448, 10241, 21938, 585, 11, 51864], temperature=0.0, avg_logprob=-0.1512395151845225, compression_ratio=2.0474934036939314, no_speech_prob=0.024042272940278053, words=[WordMetrics(word=' Ну,', start=np.float64(116.64), end=np.float64(117.08), probability=np.float64(0.9213927984237671)), WordMetrics(word=' смотрите,', start=np.float64(117.08), end=np.float64(117.52), probability=np.float64(0.997063934803009)), WordMetrics(word=' если', start=np.float64(117.64), end=np.float64(117.82), probability=np.float64(0.9991901516914368)), WordMetrics(word=' через', start=np.float64(117.82), end=np.float64(118.02), probability=np.float64(0.9998310804367065)), WordMetrics(word=' месяц,', start=np.float64(118.02), end=np.float64(118.44), probability=np.float64(0.9999274611473083)), WordMetrics(word=' тогда', start=np.float64(118.44), end=np.float64(118.64), probability=np.float64(0.8882402181625366)), WordMetrics(word=' то,', start=np.float64(118.64), end=np.float64(118.78), probability=np.float64(0.9996824264526367)), WordMetrics(word=' что', start=np.float64(118.86), end=np.float64(119.0), probability=np.float64(0.9999556541442871)), WordMetrics(word=' я', start=np.float64(119.0), end=np.float64(119.12), probability=np.float64(0.9999798536300659)), WordMetrics(word=' вам', start=np.float64(119.12), end=np.float64(119.32), probability=np.float64(0.9784044623374939)), WordMetrics(word=' сейчас', start=np.float64(119.32), end=np.float64(119.58), probability=np.float64(0.9999254941940308)), WordMetrics(word=' скажу,', start=np.float64(119.58), end=np.float64(119.98), probability=np.float64(0.9475612044334412))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.4909031391143799, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5521252751350403, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.5187675356864929, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=34, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.00011365192767698318, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9998462200164795, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=4.008347968920134e-05, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=17, seek=12000, start=np.float64(120.0), end=np.float64(122.22), text=' оно абсолютно никакой силы иметь не будет.', tokens=[50366, 25369, 35060, 23127, 1700, 24776, 698, 7604, 9108, 1725, 7306, 13, 50481], temperature=0.0, avg_logprob=-0.2261867966762809, compression_ratio=2.2687927107061503, no_speech_prob=0.1273680180311203, words=[WordMetrics(word=' оно', start=np.float64(120.0), end=np.float64(120.16), probability=np.float64(0.021004052832722664)), WordMetrics(word=' абсолютно', start=np.float64(120.16), end=np.float64(120.56), probability=np.float64(0.9792332053184509)), WordMetrics(word=' никакой', start=np.float64(120.56), end=np.float64(121.16), probability=np.float64(0.9970600605010986)), WordMetrics(word=' силы', start=np.float64(121.16), end=np.float64(121.52), probability=np.float64(0.9679909944534302)), WordMetrics(word=' иметь', start=np.float64(121.52), end=np.float64(121.92), probability=np.float64(0.9941596984863281)), WordMetrics(word=' не', start=np.float64(121.92), end=np.float64(122.02), probability=np.float64(0.9980753660202026)), WordMetrics(word=' будет.', start=np.float64(122.02), end=np.float64(122.22), probability=np.float64(0.9971497654914856))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.4680241048336029, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5282551050186157, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.4099824130535126, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=30, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.0005579812568612397, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9988572597503662, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0005848034052178264, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=18, seek=12000, start=np.float64(122.3), end=np.float64(124.02), text=' Потому что через месяц у нас будут другие условия.', tokens=[50485, 23671, 2143, 17341, 29329, 1814, 1595, 6519, 20393, 32108, 34974, 7409, 13, 50569], temperature=0.0, avg_logprob=-0.2261867966762809, compression_ratio=2.2687927107061503, no_speech_prob=0.1273680180311203, words=[WordMetrics(word=' Потому', start=np.float64(122.3), end=np.float64(122.4), probability=np.float64(0.5547213554382324)), WordMetrics(word=' что', start=np.float64(122.4), end=np.float64(122.48), probability=np.float64(0.9926611185073853)), WordMetrics(word=' через', start=np.float64(122.48), end=np.float64(122.68), probability=np.float64(0.9976728558540344)), WordMetrics(word=' месяц', start=np.float64(122.68), end=np.float64(122.98), probability=np.float64(0.999675840139389)), WordMetrics(word=' у', start=np.float64(122.98), end=np.float64(123.06), probability=np.float64(0.9989263415336609)), WordMetrics(word=' нас', start=np.float64(123.06), end=np.float64(123.14), probability=np.float64(0.9998776912689209)), WordMetrics(word=' будут', start=np.float64(123.14), end=np.float64(123.3), probability=np.float64(0.999776303768158)), WordMetrics(word=' другие', start=np.float64(123.3), end=np.float64(123.54), probability=np.float64(0.9992741942405701)), WordMetrics(word=' условия.', start=np.float64(123.54), end=np.float64(124.02), probability=np.float64(0.9997638761997223))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5430489182472229, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.554533839225769, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.304447203874588, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=54, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.002861790591850877, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9970729351043701, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=6.52833332424052e-05, unit=None, description=None)], description=None)},
# ...
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=61, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.00013042287901043892, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9998553991317749, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=1.4149338312563486e-05, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=37, seek=15000, start=np.float64(174.68), end=np.float64(175.42), text=' Тогда что говорит?', tokens=[51599, 46357, 2143, 25083, 30, 51641], temperature=0.0, avg_logprob=-0.2166886700841481, compression_ratio=2.011655011655012, no_speech_prob=0.0041984557174146175, words=[WordMetrics(word=' Тогда', start=np.float64(174.68), end=np.float64(175.04), probability=np.float64(0.35175108909606934)), WordMetrics(word=' что', start=np.float64(175.04), end=np.float64(175.2), probability=np.float64(0.9981285929679871)), WordMetrics(word=' говорит?', start=np.float64(175.2), end=np.float64(175.42), probability=np.float64(0.9979932308197021))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5859391093254089, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.6251538991928101, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.09050793945789337, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=43, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=9.187365321849938e-06, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9999825954437256, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=8.178428288374562e-06, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=38, seek=15000, start=np.float64(175.56), end=np.float64(176.9), text=' В любом случае машина продается.', tokens=[51649, 2348, 9875, 1253, 26425, 19820, 7861, 11354, 6970, 13, 51716], temperature=0.0, avg_logprob=-0.2166886700841481, compression_ratio=2.011655011655012, no_speech_prob=0.0041984557174146175, words=[WordMetrics(word=' В', start=np.float64(175.56), end=np.float64(175.64), probability=np.float64(0.8425720930099487)), WordMetrics(word=' любом', start=np.float64(175.64), end=np.float64(175.8), probability=np.float64(0.9982551634311676)), WordMetrics(word=' случае', start=np.float64(175.8), end=np.float64(176.04), probability=np.float64(0.9999488592147827)), WordMetrics(word=' машина', start=np.float64(176.04), end=np.float64(176.5), probability=np.float64(0.5343200713396072)), WordMetrics(word=' продается.', start=np.float64(176.5), end=np.float64(176.9), probability=np.float64(0.9647603929042816))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.43432366847991943, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.4939837157726288, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.3695599436759949, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=63, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.005436272360384464, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9943591952323914, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.00020457555365283042, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=39, seek=15000, start=np.float64(176.9), end=np.float64(179.36), text=' Это какое-то имущество, какая-то собственность.', tokens=[51730, 6684, 37932, 12, 860, 7604, 585, 4805, 9631, 11, 29334, 12, 860, 49863, 3167, 13, 51864], temperature=0.0, avg_logprob=-0.2166886700841481, compression_ratio=2.011655011655012, no_speech_prob=0.0041984557174146175, words=[WordMetrics(word=' Это', start=np.float64(176.9), end=np.float64(177.12), probability=np.float64(0.9962499737739563)), WordMetrics(word=' какое', start=np.float64(177.12), end=np.float64(177.72), probability=np.float64(0.9991692304611206)), WordMetrics(word='-то', start=np.float64(177.72), end=np.float64(177.84), probability=np.float64(0.9999819993972778)), WordMetrics(word=' имущество,', start=np.float64(177.84), end=np.float64(178.46), probability=np.float64(0.9999243170022964)), WordMetrics(word=' какая', start=np.float64(178.48), end=np.float64(178.7), probability=np.float64(0.9358938932418823)), WordMetrics(word='-то', start=np.float64(178.7), end=np.float64(178.9), probability=np.float64(0.999992847442627)), WordMetrics(word=' собственность.', start=np.float64(178.9), end=np.float64(179.36), probability=np.float64(0.9987090528011322))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.566111147403717, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5139396786689758, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.48907673358917236, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=16, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=2.7281571419734973e-06, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9659147262573242, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.034082528203725815, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=40, seek=18000, start=np.float64(182.10000000000002), end=np.float64(182.46), text=' Пожалуйста.', tokens=[50365, 2608, 27315, 13, 50415], temperature=0.0, avg_logprob=-0.40454747126652646, compression_ratio=1.448051948051948, no_speech_prob=0.007873660884797573, words=[WordMetrics(word=' Пожалуйста.', start=np.float64(182.10000000000002), end=np.float64(182.46), probability=np.float64(0.93330979347229))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.5736625790596008, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.6029921174049377, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.6042569875717163, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=26, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=1.3373510228120722e-05, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9419214129447937, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.05806516483426094, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=41, seek=18000, start=np.float64(184.46), end=np.float64(185.42), text=' Я вас понял.', tokens=[50415, 4857, 10655, 37975, 13, 50465], temperature=0.0, avg_logprob=-0.40454747126652646, compression_ratio=1.448051948051948, no_speech_prob=0.007873660884797573, words=[WordMetrics(word=' Я', start=np.float64(184.46), end=np.float64(184.82), probability=np.float64(0.9913363456726074)), WordMetrics(word=' вас', start=np.float64(184.82), end=np.float64(185.1), probability=np.float64(0.9345682263374329)), WordMetrics(word=' понял.', start=np.float64(185.1), end=np.float64(185.42), probability=np.float64(0.999922513961792))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.6234963536262512, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.6016875505447388, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.6744199395179749, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=37, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=8.917598279367667e-06, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9999804496765137, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=1.0623452908475883e-05, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=42, seek=18000, start=np.float64(185.54), end=np.float64(187.5), text=' Все, Александр, сейчас, да, не могу говорить клиентам.', tokens=[50465, 18029, 11, 44938, 481, 11, 10241, 11, 8995, 11, 1725, 22951, 32460, 33504, 5243, 1685, 13, 50715], temperature=0.0, avg_logprob=-0.40454747126652646, compression_ratio=1.448051948051948, no_speech_prob=0.007873660884797573, words=[WordMetrics(word=' Все,', start=np.float64(185.54), end=np.float64(185.72), probability=np.float64(0.824021577835083)), WordMetrics(word=' Александр,', start=np.float64(185.82), end=np.float64(186.32), probability=np.float64(0.9983969330787659)), WordMetrics(word=' сейчас,', start=np.float64(186.32), end=np.float64(186.42), probability=np.float64(0.9403338432312012)), WordMetrics(word=' да,', start=np.float64(186.46), end=np.float64(186.58), probability=np.float64(0.999813973903656)), WordMetrics(word=' не', start=np.float64(186.58), end=np.float64(186.66), probability=np.float64(0.9993466734886169)), WordMetrics(word=' могу', start=np.float64(186.66), end=np.float64(186.82), probability=np.float64(0.9999804496765137)), WordMetrics(word=' говорить', start=np.float64(186.82), end=np.float64(187.08), probability=np.float64(0.9997909665107727)), WordMetrics(word=' клиентам.', start=np.float64(187.08), end=np.float64(187.5), probability=np.float64(0.6897276143232981))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.536042332649231, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.5788998603820801, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.49518465995788574, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=36, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.012517311610281467, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9836276769638062, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.0038550044409930706, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=43, seek=18000, start=np.float64(187.52), end=np.float64(188.5), text=' Всего доброго за обращение.', tokens=[50715, 10779, 4353, 35620, 2350, 4396, 3348, 18747, 5627, 13, 50765], temperature=0.0, avg_logprob=-0.40454747126652646, compression_ratio=1.448051948051948, no_speech_prob=0.007873660884797573, words=[WordMetrics(word=' Всего', start=np.float64(187.52), end=np.float64(187.68), probability=np.float64(0.9993562996387482)), WordMetrics(word=' доброго', start=np.float64(187.68), end=np.float64(188.0), probability=np.float64(0.9999471306800842)), WordMetrics(word=' за', start=np.float64(188.0), end=np.float64(188.1), probability=np.float64(0.9513498544692993)), WordMetrics(word=' обращение.', start=np.float64(188.1), end=np.float64(188.5), probability=np.float64(0.9982892076174418))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.3981636166572571, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.3932940363883972, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.4708414077758789, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=27, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.022547217085957527, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.18889883160591125, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.7885539531707764, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=44, seek=18000, start=np.float64(188.5), end=np.float64(188.76), text=' Спасибо.', tokens=[50765, 29219, 13, 50815], temperature=0.0, avg_logprob=-0.40454747126652646, compression_ratio=1.448051948051948, no_speech_prob=0.007873660884797573, words=[WordMetrics(word=' Спасибо.', start=np.float64(188.5), end=np.float64(188.76), probability=np.float64(0.9995080232620239))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=0.4135324954986572, unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=0.39979174733161926, unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=0.36229005455970764, unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=42, unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=0.004614169243723154, unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=0.9931017160415649, unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=0.002284157555550337, unit=None, description=None)], description=None)},
#   WhisperMetrics(id=45, seek=18000, start=np.float64(189.06), end=np.float64(189.42), text=' Успехов.', tokens=[50815, 6523, 6461, 8008, 1055, 13, 50865], temperature=0.0, avg_logprob=-0.40454747126652646, compression_ratio=1.448051948051948, no_speech_prob=0.007873660884797573, words=[WordMetrics(word=' Успехов.', start=np.float64(189.06), end=np.float64(189.42), probability=np.float64(0.9964725971221924))]))]
