# %%
import torch

# %%
if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
    for i in range(num_gpus):
        gpu_name = torch.cuda.get_device_name(i)
        print(f"GPU {i}: {gpu_name}")
else:
    print("CUDA is not available.")
# Out:
# GPU 0: AMD Radeon RX 9070 XT
# GPU 1: AMD Ryzen 7 7800X3D 8-Core Processor

# %%
DEVICE="cuda:0"

# %%
DATASET_DIR = "../dataset"

ORIG_FILE = "./output/original.wav"
SPEAKER1_FILE = "./output/speaker1.wav"
SPEAKER2_FILE = "./output/speaker2.wav"
SPEAKER1_METRICS_FILE = "./output/speaker1.json"
SPEAKER2_METRICS_FILE = "./output/speaker2.json"

SPEAKER1_DIR = "./output/speaker1"
SPEAKER2_DIR = "./output/speaker2"

MIN_SEGMENT_LENGTH_SEC = 0.1
STOP_PHRASES = [
    "ДИНАМИЧНАЯ МУЗЫКА",
    "Продолжение следует.",
    "Продолжение следует...",
]
STOP_PHRASE_LENGTH_DELTA = 5

# %%
PER_SEGMENT_PROCESSORS = dict()
PER_CHANNEL_PROCESSORS = dict()

# %%
import os

os.makedirs(SPEAKER1_DIR, exist_ok=True)
os.makedirs(SPEAKER2_DIR, exist_ok=True)

# %%
import random

input_file = random.choice(os.listdir(DATASET_DIR))
input_file = f"{DATASET_DIR}/" + input_file
input_file
# Out:
# '../dataset/mix_13100_13137__2025_10_01__09_19_59_723.mp3'

# %%
import pydub

audio = pydub.AudioSegment.from_file(input_file)

try:
    left_channel, right_channel = audio.split_to_mono()
except ValueError as ex:
    raise ValueError("Input file must be stereo.") from ex

left_channel.export(SPEAKER1_FILE, format="wav")
right_channel.export(SPEAKER2_FILE, format="wav")
audio.export(ORIG_FILE, format="wav")
# Out:
# <_io.BufferedRandom name='./output/original.wav'>

# %%
import whisper
whispermodel = whisper.load_model("large").to(DEVICE)

# %%
from typing import Generator, Tuple

def filter_out(segment_data: dict) -> bool:
    # Removing short segments
    if (segment_data["end"] - segment_data["start"]) < MIN_SEGMENT_LENGTH_SEC:
        return True

    # Removing segments that contain stop_phrases
    matching_stop_phrases = [s for s in STOP_PHRASES if s.lower() in segment_data["text"].lower()]
    if matching_stop_phrases:
        # Remove the segment if it contains only a stop phrase
        if max(map(len, matching_stop_phrases)) + STOP_PHRASE_LENGTH_DELTA > len(segment_data["text"].strip()):
            return True
            
    return False

def segmentize(source: str, segments_dir: str) -> Generator[Tuple[dict, str]]:
    transcription = whispermodel.transcribe(source, word_timestamps=True, language='ru')
    audio = pydub.AudioSegment.from_file(source)
    for segment_data in transcription['segments']:
        if filter_out(segment_data):
            continue
        start = float(segment_data['start']) * 1000
        end = float(segment_data['end']) * 1000
        path = f"{segments_dir}/{segment_data['id']}.wav"
        audio[start:end].export(path, format="wav")
        yield (segment_data, path)

# %%
def show(vals: dict) -> dict:
    keys = ["id", "start", "end", "text"]
    return {k: vals[0][k] for k in keys}
list(map(show, segmentize(SPEAKER1_FILE, SPEAKER1_DIR)))
# Out:
# [{'id': 0,
#   'start': np.float64(18.220000000000002),
#   'end': np.float64(21.02),
#   'text': ' Доброе утро!'},
#  {'id': 1,
#   'start': np.float64(30.0),
#   'end': np.float64(32.82),
#   'text': ' Уже какой-то выбор сделал в пользу какого-то бренда?'},
#  {'id': 2,
#   'start': np.float64(33.96),
#   'end': np.float64(36.92),
#   'text': ' Угу, супер, с мобилем познакомились, понимаете, с Drive прошли?'},
#  {'id': 3,
#   'start': np.float64(40.8),
#   'end': np.float64(43.1),
#   'text': ' Угу, с комплектацией определились, правильно?'},
#  {'id': 4,
#   'start': np.float64(46.58),
#   'end': np.float64(47.48),
#   'text': ' Супер, отлично.'},
#  {'id': 5,
#   'start': np.float64(48.72),
#   'end': np.float64(51.76),
#   'text': ' Вы рассматриваете как покупку, в течение какого времени?'},
#  {'id': 6,
#   'start': np.float64(54.56),
#   'end': np.float64(55.16),
#   'text': ' Угу.'},
#  {'id': 7,
#   'start': np.float64(57.18),
#   'end': np.float64(59.7),
#   'text': ' Так, вы когда тест-драйв проходили,'},
#  {'id': 8,
#   'start': np.float64(59.7),
#   'end': np.float64(59.98),
#   'text': ' какие предложения, какие предложения,'},
#  {'id': 9,
#   'start': np.float64(59.98),
#   'end': np.float64(61.38),
#   'text': ' какие-то сделали расчеты предварительные,'},
#  {'id': 10,
#   'start': np.float64(61.44),
#   'end': np.float64(63.5),
#   'text': ' может, есть уже какие-то понимания по ценам на бирже?'},
#  {'id': 11,
#   'start': np.float64(67.18),
#   'end': np.float64(67.62),
#   'text': ' Угу.'},
#  {'id': 12,
#   'start': np.float64(69.06),
#   'end': np.float64(69.5),
#   'text': ' Да.'},
#  {'id': 13,
#   'start': np.float64(71.14),
#   'end': np.float64(73.14),
#   'text': ' Ну, я понял, за сколько предложили снизить крат?'},
#  {'id': 14,
#   'start': np.float64(80.12),
#   'end': np.float64(80.56),
#   'text': ' Угу.'},
#  {'id': 15,
#   'start': np.float64(81.60000000000001),
#   'end': np.float64(82.04),
#   'text': ' Угу.'},
#  {'id': 16,
#   'start': np.float64(84.10000000000001),
#   'end': np.float64(84.54),
#   'text': ' Понял.'},
#  {'id': 17,
#   'start': np.float64(84.94),
#   'end': np.float64(86.6),
#   'text': ' На какую сумму сами рассчитываете?'},
#  {'id': 18,
#   'start': np.float64(86.72),
#   'end': np.float64(88.54),
#   'text': ' И каким способом вообще планируете покупку?'},
#  {'id': 19,
#   'start': np.float64(88.6),
#   'end': np.float64(89.7),
#   'text': ' Там будет у вас кредит наличный?'},
#  {'id': 21,
#   'start': np.float64(93.62),
#   'end': np.float64(94.18),
#   'text': ' Угу.'},
#  {'id': 22,
#   'start': np.float64(94.18),
#   'end': np.float64(96.48),
#   'text': ' Ну, рассрочка, да, вам рассказали, там 60% износа.'},
#  {'id': 23,
#   'start': np.float64(99.44),
#   'end': np.float64(102.06),
#   'text': ' 60% должно быть износно, 3 года рассрочка будет.'},
#  {'id': 24,
#   'start': np.float64(104.9),
#   'end': np.float64(105.46),
#   'text': ' Угу.'},
#  {'id': 26,
#   'start': np.float64(111.4),
#   'end': np.float64(111.96),
#   'text': ' Угу.'},
#  {'id': 27,
#   'start': np.float64(112.02),
#   'end': np.float64(113.64),
#   'text': ' Когда будет удобно, когда подъехать,'},
#  {'id': 28,
#   'start': np.float64(113.64),
#   'end': np.float64(115.04),
#   'text': ' отменить автомобиль, сделать расчеты?'},
#  {'id': 29,
#   'start': np.float64(117.9),
#   'end': np.float64(119.44),
#   'text': ' Да как я без ваших...'},
#  {'id': 30,
#   'start': np.float64(119.44),
#   'end': np.float64(121.72),
#   'text': ' без вашей оценки, как я могу...'},
#  {'id': 31,
#   'start': np.float64(121.72),
#   'end': np.float64(124.68),
#   'text': ' Не знаю, стоимость каска, не знаю...'},
#  {'id': 32,
#   'start': np.float64(127.6),
#   'end': np.float64(128.98),
#   'text': ' Доповозу, у меня ваши пожелания.'},
#  {'id': 33,
#   'start': np.float64(134.38),
#   'end': np.float64(134.9),
#   'text': ' Угу.'},
#  {'id': 34,
#   'start': np.float64(135.28),
#   'end': np.float64(137.42),
#   'text': ' И вы взяли это за основу цифры?'},
#  {'id': 35,
#   'start': np.float64(137.5),
#   'end': np.float64(139.0),
#   'text': ' Там же ни диагностики, ничего не было.'},
#  {'id': 36,
#   'start': np.float64(142.4),
#   'end': np.float64(142.92),
#   'text': ' Угу.'},
#  {'id': 37,
#   'start': np.float64(144.96),
#   'end': np.float64(145.48),
#   'text': ' Угу.'},
#  {'id': 39,
#   'start': np.float64(149.44),
#   'end': np.float64(152.5),
#   'text': ' Ну, это везде скидка одинаковая, она от производителя идет, а не от Автополя.'},
#  {'id': 40,
#   'start': np.float64(159.54),
#   'end': np.float64(161.54),
#   'text': ' Нет, везде скидка одинаковая, 400 тысяч.'},
#  {'id': 41,
#   'start': np.float64(161.9),
#   'end': np.float64(163.06),
#   'text': ' Вряд ли такое может быть.'},
#  {'id': 42,
#   'start': np.float64(165.42),
#   'end': np.float64(168.64),
#   'text': ' Нет, поддержки просто, они одинаковые, может там просто старая информация была.'},
#  {'id': 43,
#   'start': np.float64(168.84),
#   'end': np.float64(172.98),
#   'text': ' А так поддержки везде одинаковые, от производителя, то есть 400 тысяч, все верно, скидка по трейдингу.'},
#  {'id': 44,
#   'start': np.float64(173.34),
#   'end': np.float64(175.14),
#   'text': ' Я так понимаю, были несколько дней назад, да?'},
#  {'id': 45,
#   'start': np.float64(175.88),
#   'end': np.float64(176.28),
#   'text': ' Да.'},
#  {'id': 46,
#   'start': np.float64(176.74),
#   'end': np.float64(178.98),
#   'text': ' Потому что скидка по трейдингу уже не 400, а 350.'},
#  {'id': 47,
#   'start': np.float64(179.02),
#   'end': np.float64(179.42),
#   'text': ' Да.'},
#  {'id': 50,
#   'start': np.float64(180.1),
#   'end': np.float64(181.4),
#   'text': ' С первого числа.'},
#  {'id': 51,
#   'start': np.float64(182.32),
#   'end': np.float64(182.82),
#   'text': ' Да.'},
#  {'id': 52,
#   'start': np.float64(182.94),
#   'end': np.float64(184.1),
#   'text': ' Фиксированная также везде, да.'},
#  {'id': 53,
#   'start': np.float64(184.48),
#   'end': np.float64(188.72),
#   'text': ' 3 700 вам предложили, когда трейдинг был 400, сейчас 350.'},
#  {'id': 54,
#   'start': np.float64(189.08),
#   'end': np.float64(191.38),
#   'text': ' То есть, тут на 50 тысяч она уже вырастает, к сожалению.'},
#  {'id': 55,
#   'start': np.float64(192.36),
#   'end': np.float64(193.12),
#   'text': ' 3 750.'},
#  {'id': 56,
#   'start': np.float64(195.38),
#   'end': np.float64(205.26),
#   'text': ' Смотрите, если вы готовы договариваться, там есть интерес, правда, купить автомобиль, да, рассматривайте кредит или просрочку, могу вам предложить на 100 тысяч сократить цену от предложения Автополя.'},
#  {'id': 57,
#   'start': np.float64(205.88),
#   'end': np.float64(209.4),
#   'text': ' Но тут нужно понимание, то есть, если вы готовы, то...'},
#  {'id': 60,
#   'start': np.float64(209.48),
#   'end': np.float64(219.54),
#   'text': ' Если вы готовы, то, соответственно, подъехать и сделать полную диагностику автомобиля, чтобы я понимал, в чем вообще смысл трейдинга, это когда вы оцениваете автомобиль, мне говорят, за сколько мы можем перепродать.'},
#  {'id': 61,
#   'start': np.float64(219.66),
#   'end': np.float64(224.16),
#   'text': ' И я могу вот этот весь заработок пожертвовать в пользу того, чтобы сделать еще скидку на автомобиль.'},
#  {'id': 62,
#   'start': np.float64(224.4),
#   'end': np.float64(228.5),
#   'text': ' Чтобы мне понять, сколько я могу еще сделать дополнительно, для этого и проводится как раз диагностика.'},
#  {'id': 63,
#   'start': np.float64(228.72),
#   'end': np.float64(232.2),
#   'text': ' У меня, например, менеджер по трейдингу говорит, мы продадим его плюс там 150 тысяч.'},
#  {'id': 64,
#   'start': np.float64(232.36),
#   'end': np.float64(235.36),
#   'text': ' Я говорю, хорошо, эти 150 тысяч я вам делаю скидку на автомобиль.'},
#  {'id': 65,
#   'start': np.float64(235.58),
#   'end': np.float64(237.96),
#   'text': ' То есть, вот таким способом финальная цена и достигается.'},
#  {'id': 66,
#   'start': np.float64(238.18),
#   'end': np.float64(238.3),
#   'text': ' Да.'},
#  {'id': 67,
#   'start': np.float64(238.3),
#   'end': np.float64(245.44),
#   'text': ' В любом случае, так скажем, мы находимся не в самом городе, да, у нас нет там пешеходного трафика.'},
#  {'id': 68,
#   'start': np.float64(245.52),
#   'end': np.float64(247.88),
#   'text': ' Мы в основном работаем с людьми, которые по телефону обращаются.'},
#  {'id': 69,
#   'start': np.float64(248.5),
#   'end': np.float64(251.14),
#   'text': ' Вот мы возле кольца стоим напротив MegaparNAS, знаете.'},
#  {'id': 70,
#   'start': np.float64(254.14),
#   'end': np.float64(257.48),
#   'text': ' Да, вот напротив, внутренняя сторона кольца, здесь мы находимся в краске.'},
#  {'id': 71,
#   'start': np.float64(257.66),
#   'end': np.float64(265.02),
#   'text': ' Ну и, собственно, перебиваем предложение вот таким способом, когда уже есть предложение на руках, делаем просто дешевле, там, до 100 тысяч рублей.'},
#  {'id': 72,
#   'start': np.float64(265.94),
#   'end': np.float64(266.34),
#   'text': ' Вот.'},
#  {'id': 73,
#   'start': np.float64(266.38),
#   'end': np.float64(267.8),
#   'text': ' Если, правда, есть интерес, то...'},
#  {'id': 74,
#   'start': np.float64(268.3),
#   'end': np.float64(270.5),
#   'text': ' Как раз-таки, самые лучшие цены можно у нас получить.'},
#  {'id': 75,
#   'start': np.float64(270.78),
#   'end': np.float64(276.98),
#   'text': ' Там есть и по цвету еще определились, то есть, цветовые палитры у нас есть сейчас в наличии голубой, черный, зеленый.'},
#  {'id': 76,
#   'start': np.float64(279.38),
#   'end': np.float64(280.92),
#   'text': ' Вот зеленый есть тоже в наличии.'},
#  {'id': 77,
#   'start': np.float64(281.52),
#   'end': np.float64(286.06),
#   'text': ' А так уже дальше зависит от вас, когда вы хотите приобретать.'},
#  {'id': 78,
#   'start': np.float64(286.48),
#   'end': np.float64(291.06),
#   'text': ' То есть, чем раньше, тем дешевле, потому что сейчас весь сбор будет повышать цены на автомобиль.'},
#  {'id': 79,
#   'start': np.float64(291.3),
#   'end': np.float64(294.46),
#   'text': ' Они могут там на новые.'},
#  {'id': 80,
#   'start': np.float64(296.04),
#   'end': np.float64(296.9),
#   'text': ' Да, это понятно.'},
#  {'id': 81,
#   'start': np.float64(296.9),
#   'end': np.float64(298.22),
#   'text': ' Но тут видите, как они делают.'},
#  {'id': 82,
#   'start': np.float64(298.4),
#   'end': np.float64(300.38),
#   'text': ' Допустим, да, старый рынок был 400, сейчас 350.'},
#  {'id': 83,
#   'start': np.float64(300.76),
#   'end': np.float64(304.7),
#   'text': ' По сути, цена от автомобиля осталась той же самой, а автомобиль вырос на 50 тысяч рублей.'},
#  {'id': 84,
#   'start': np.float64(304.98),
#   'end': np.float64(306.7),
#   'text': ' То есть, вот так вот из-за этого.'},
#  {'id': 85,
#   'start': np.float64(307.72),
#   'end': np.float64(314.86),
#   'text': ' То же самое было в прошлом году, когда с 1 октября тоже весь сбор начал повышать цены, уже не сразу на 10% повысил цены.'},
#  {'id': 86,
#   'start': np.float64(315.76),
#   'end': np.float64(317.84),
#   'text': ' Там была скидка по семейной процентной.'}]

# %%
from typing import Callable, Any
import pathlib
import dacite

from analysis_node.messages import MetricCollection
from analysis_node.analysis.postprocessing import WhisperMetrics
from analysis_node.analysis.processors import Processor

def collect_metrics_per_segment(
    segment_file: pathlib.Path | str,
) -> Tuple[dict[str, MetricCollection], dict[str, MetricCollection]]:
    def process(processors: dict[str, Processor]) -> dict[str, MetricCollection]:
        return {
            proc_name: processor.process(segment_file)
            for proc_name, processor in processors.items()
        }

    return (
        process(PER_SEGMENT_PROCESSORS),
        process(PER_CHANNEL_PROCESSORS),
    )

def collect_metrics_per_channel(
    channel_file: pathlib.Path | str,
    segments_dir: pathlib.Path | str,
) -> Generator[
    Tuple[dict[str, MetricCollection], dict[str, MetricCollection], WhisperMetrics],
    None,
    None,
]:
    for segment_data, segment_path in segmentize(channel_file, segments_dir):
        per_segment, per_channel = collect_metrics_per_segment(segment_path)
        whisper_data = dacite.from_dict(
            data_class=WhisperMetrics,
            data=segment_data,
        )
        yield per_segment, per_channel, whisper_data

# %%
from analysis_node.analysis.processors import VadEmotionProcessor
from analysis_node.analysis.processors import AgeGenderProcessor

PER_SEGMENT_PROCESSORS["emotion"] = VadEmotionProcessor(DEVICE)
PER_CHANNEL_PROCESSORS["age_gender"] = AgeGenderProcessor("small", DEVICE)

# %%
raw_metrics = list(collect_metrics_per_channel(SPEAKER1_FILE, SPEAKER1_DIR))
raw_metrics
# Out:
# [({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6565948), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.62044114), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5084065), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(11.01968), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.34786567), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0071976567), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6449367), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=0, seek=0, start=np.float64(18.220000000000002), end=np.float64(21.02), text=' Доброе утро!', tokens=[50365, 3401, 13829, 5805, 25448, 9938, 0, 51419], temperature=0.0, avg_logprob=-0.5016349686516656, compression_ratio=0.8148148148148148, no_speech_prob=0.14720235764980316, words=[WordMetrics(word=' Доброе', start=np.float64(18.220000000000002), end=np.float64(19.62), probability=np.float64(0.8064753611882528)), WordMetrics(word=' утро!', start=np.float64(19.62), end=np.float64(21.02), probability=np.float64(0.9998990893363953))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.79231447), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6924195), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.51784056), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(22.45039), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.95763284), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.011981123), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.030386083), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=1, seek=3000, start=np.float64(30.0), end=np.float64(32.82), text=' Уже какой-то выбор сделал в пользу какого-то бренда?', tokens=[50365, 6523, 4757, 16898, 12, 860, 18061, 1717, 40653, 740, 30419, 585, 3014, 2350, 12, 860, 19603, 1008, 3444, 30, 50510], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' Уже', start=np.float64(30.0), end=np.float64(30.2), probability=np.float64(0.5203730668872595)), WordMetrics(word=' какой', start=np.float64(30.2), end=np.float64(30.54), probability=np.float64(0.8628078699111938)), WordMetrics(word='-то', start=np.float64(30.54), end=np.float64(30.7), probability=np.float64(0.9768350720405579)), WordMetrics(word=' выбор', start=np.float64(30.7), end=np.float64(31.18), probability=np.float64(0.9981077313423157)), WordMetrics(word=' сделал', start=np.float64(31.18), end=np.float64(31.38), probability=np.float64(0.5970669984817505)), WordMetrics(word=' в', start=np.float64(31.38), end=np.float64(31.6), probability=np.float64(0.3851275146007538)), WordMetrics(word=' пользу', start=np.float64(31.6), end=np.float64(32.12), probability=np.float64(0.9726666510105133)), WordMetrics(word=' какого', start=np.float64(32.12), end=np.float64(32.34), probability=np.float64(0.9805475473403931)), WordMetrics(word='-то', start=np.float64(32.34), end=np.float64(32.44), probability=np.float64(0.9886617660522461)), WordMetrics(word=' бренда?', start=np.float64(32.44), end=np.float64(32.82), probability=np.float64(0.997726301352183))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.8017285), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.68915015), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6648525), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(13.741488), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.24950564), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.008736629), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.74175775), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=2, seek=3000, start=np.float64(33.96), end=np.float64(36.92), text=' Угу, супер, с мобилем познакомились, понимаете, с Drive прошли?', tokens=[50583, 6523, 28264, 11, 32453, 1135, 11, 776, 1084, 2061, 2338, 1504, 12188, 45051, 19285, 11, 15084, 17670, 11, 776, 15622, 20567, 1675, 30, 50716], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' Угу,', start=np.float64(33.96), end=np.float64(34.56), probability=np.float64(0.6925020515918732)), WordMetrics(word=' супер,', start=np.float64(34.56), end=np.float64(35.04), probability=np.float64(0.997387021780014)), WordMetrics(word=' с', start=np.float64(35.04), end=np.float64(35.1), probability=np.float64(0.9539192914962769)), WordMetrics(word=' мобилем', start=np.float64(35.1), end=np.float64(35.42), probability=np.float64(0.8030562549829483)), WordMetrics(word=' познакомились,', start=np.float64(35.42), end=np.float64(35.9), probability=np.float64(0.998771866162618)), WordMetrics(word=' понимаете,', start=np.float64(35.92), end=np.float64(36.3), probability=np.float64(0.592528909444809)), WordMetrics(word=' с', start=np.float64(36.34), end=np.float64(36.42), probability=np.float64(0.7364067435264587)), WordMetrics(word=' Drive', start=np.float64(36.42), end=np.float64(36.54), probability=np.float64(0.32782772183418274)), WordMetrics(word=' прошли?', start=np.float64(36.54), end=np.float64(36.92), probability=np.float64(0.9978152811527252))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6317512), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5583527), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.55004287), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(21.148212), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.99201536), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0029341427), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.005050567), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=3, seek=3000, start=np.float64(40.8), end=np.float64(43.1), text=' Угу, с комплектацией определились, правильно?', tokens=[50921, 6523, 28264, 11, 776, 14380, 21579, 8392, 2345, 39305, 19285, 11, 39321, 30, 51025], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' Угу,', start=np.float64(40.8), end=np.float64(41.4), probability=np.float64(0.947133481502533)), WordMetrics(word=' с', start=np.float64(41.4), end=np.float64(41.96), probability=np.float64(0.7846521735191345)), WordMetrics(word=' комплектацией', start=np.float64(41.96), end=np.float64(42.42), probability=np.float64(0.9693262279033661)), WordMetrics(word=' определились,', start=np.float64(42.42), end=np.float64(42.86), probability=np.float64(0.9923181235790253)), WordMetrics(word=' правильно?', start=np.float64(42.92), end=np.float64(43.1), probability=np.float64(0.9993332028388977))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6186635), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.58768564), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.33590823), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(20.742424), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.95760334), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.003693499), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.038703192), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=4, seek=3000, start=np.float64(46.58), end=np.float64(47.48), text=' Супер, отлично.', tokens=[51199, 2933, 6907, 1135, 11, 2943, 40955, 13, 51242], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' Супер,', start=np.float64(46.58), end=np.float64(47.18), probability=np.float64(0.9846852421760559)), WordMetrics(word=' отлично.', start=np.float64(47.18), end=np.float64(47.48), probability=np.float64(0.9987874627113342))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7012213), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.62905145), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.54203373), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(18.965218), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.22239095), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.009701047), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.76790804), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=5, seek=3000, start=np.float64(48.72), end=np.float64(51.76), text=' Вы рассматриваете как покупку, в течение какого времени?', tokens=[51308, 11886, 23345, 34476, 481, 2739, 17670, 3014, 34005, 4401, 11, 740, 1069, 44274, 3014, 2350, 26436, 30, 51456], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' Вы', start=np.float64(48.72), end=np.float64(49.32), probability=np.float64(0.967460036277771)), WordMetrics(word=' рассматриваете', start=np.float64(49.32), end=np.float64(49.88), probability=np.float64(0.9938199043273925)), WordMetrics(word=' как', start=np.float64(49.88), end=np.float64(50.12), probability=np.float64(0.765433669090271)), WordMetrics(word=' покупку,', start=np.float64(50.12), end=np.float64(50.64), probability=np.float64(0.997376412153244)), WordMetrics(word=' в', start=np.float64(50.64), end=np.float64(50.68), probability=np.float64(0.9971791505813599)), WordMetrics(word=' течение', start=np.float64(50.68), end=np.float64(50.86), probability=np.float64(0.959110677242279)), WordMetrics(word=' какого', start=np.float64(50.86), end=np.float64(51.48), probability=np.float64(0.9993666112422943)), WordMetrics(word=' времени?', start=np.float64(51.48), end=np.float64(51.76), probability=np.float64(0.9984341263771057))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.58427733), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5342005), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6092235), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(40.670105), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9834516), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0101979915), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.006350506), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=6, seek=3000, start=np.float64(54.56), end=np.float64(55.16), text=' Угу.', tokens=[51599, 6523, 28264, 13, 51627], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' Угу.', start=np.float64(54.56), end=np.float64(55.16), probability=np.float64(0.9722874164581299))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.8135347), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7180333), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5043831), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(37.727356), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9617261), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.027397426), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0108764265), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=7, seek=3000, start=np.float64(57.18), end=np.float64(59.7), text=' Так, вы когда тест-драйв проходили,', tokens=[51727, 8770, 11, 2840, 8874, 41699, 12, 856, 481, 3183, 859, 39782, 5435, 11, 51852], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' Так,', start=np.float64(57.18), end=np.float64(57.78), probability=np.float64(0.9899210929870605)), WordMetrics(word=' вы', start=np.float64(57.78), end=np.float64(58.38), probability=np.float64(0.9882331490516663)), WordMetrics(word=' когда', start=np.float64(58.38), end=np.float64(58.66), probability=np.float64(0.9882054328918457)), WordMetrics(word=' тест', start=np.float64(58.66), end=np.float64(58.98), probability=np.float64(0.2981746792793274)), WordMetrics(word='-драйв', start=np.float64(58.98), end=np.float64(59.22), probability=np.float64(0.9832537651062012)), WordMetrics(word=' проходили,', start=np.float64(59.22), end=np.float64(59.7), probability=np.float64(0.998672366142273))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.77250135), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6531583), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5217186), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(34.171207), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9937405), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0011051063), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.005154327), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=8, seek=3000, start=np.float64(59.7), end=np.float64(59.98), text=' какие предложения, какие предложения,', tokens=[51857, 19971, 40373, 5332, 11, 19971, 40373, 5332, 11, 51864], temperature=0.0, avg_logprob=-0.29421196299150953, compression_ratio=1.99644128113879, no_speech_prob=0.022274017333984375, words=[WordMetrics(word=' какие', start=np.float64(59.7), end=np.float64(59.9), probability=np.float64(0.9484629034996033)), WordMetrics(word=' предложения,', start=np.float64(59.9), end=np.float64(59.98), probability=np.float64(0.5247803647071123)), WordMetrics(word=' какие', start=np.float64(59.98), end=np.float64(59.98), probability=np.float64(0.4843016266822815)), WordMetrics(word=' предложения,', start=np.float64(59.98), end=np.float64(59.98), probability=np.float64(0.8238963782787323))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.76495475), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6760288), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.41427606), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(26.76065), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.98824537), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0065175164), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0052371584), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=9, seek=5998, start=np.float64(59.98), end=np.float64(61.38), text=' какие-то сделали расчеты предварительные,', tokens=[50365, 19971, 12, 860, 44780, 7459, 753, 18810, 8048, 21291, 7809, 4970, 11, 50437], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' какие', start=np.float64(59.98), end=np.float64(59.98), probability=np.float64(0.01167235802859068)), WordMetrics(word='-то', start=np.float64(59.98), end=np.float64(59.98), probability=np.float64(0.9287288784980774)), WordMetrics(word=' сделали', start=np.float64(59.98), end=np.float64(60.26), probability=np.float64(0.520455002784729)), WordMetrics(word=' расчеты', start=np.float64(60.26), end=np.float64(60.7), probability=np.float64(0.9006065328915914)), WordMetrics(word=' предварительные,', start=np.float64(60.7), end=np.float64(61.38), probability=np.float64(0.8144997507333755))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.8258424), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.71485186), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.38569236), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(26.133442), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9944623), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0031220813), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0024155008), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=10, seek=5998, start=np.float64(61.44), end=np.float64(63.5), text=' может, есть уже какие-то понимания по ценам на бирже?', tokens=[50440, 8689, 11, 5640, 7520, 19971, 12, 860, 15084, 8831, 2801, 39821, 1685, 1470, 1268, 4490, 4757, 30, 50548], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' может,', start=np.float64(61.44), end=np.float64(61.52), probability=np.float64(0.6708123683929443)), WordMetrics(word=' есть', start=np.float64(61.56), end=np.float64(61.72), probability=np.float64(0.970996081829071)), WordMetrics(word=' уже', start=np.float64(61.72), end=np.float64(61.82), probability=np.float64(0.7691905498504639)), WordMetrics(word=' какие', start=np.float64(61.82), end=np.float64(62.04), probability=np.float64(0.9413930773735046)), WordMetrics(word='-то', start=np.float64(62.04), end=np.float64(62.12), probability=np.float64(0.9964310824871063)), WordMetrics(word=' понимания', start=np.float64(62.12), end=np.float64(62.54), probability=np.float64(0.9847829937934875)), WordMetrics(word=' по', start=np.float64(62.54), end=np.float64(62.64), probability=np.float64(0.9257416725158691)), WordMetrics(word=' ценам', start=np.float64(62.64), end=np.float64(62.94), probability=np.float64(0.9958010613918304)), WordMetrics(word=' на', start=np.float64(62.94), end=np.float64(63.06), probability=np.float64(0.5588926672935486)), WordMetrics(word=' бирже?', start=np.float64(63.06), end=np.float64(63.5), probability=np.float64(0.791632334391276))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.43390608), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.4055716), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.40584403), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(29.483753), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.98510265), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.006306081), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.008591357), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=11, seek=5998, start=np.float64(67.18), end=np.float64(67.62), text=' Угу.', tokens=[50745, 6523, 28264, 13, 50754], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' Угу.', start=np.float64(67.18), end=np.float64(67.62), probability=np.float64(0.624345451593399))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.49776718), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.45013046), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.4904115), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(46.715813), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.18982558), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7731322), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.037042174), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=12, seek=5998, start=np.float64(69.06), end=np.float64(69.5), text=' Да.', tokens=[50835, 9149, 13, 50846], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' Да.', start=np.float64(69.06), end=np.float64(69.5), probability=np.float64(0.29498612880706787))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.74710745), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6624342), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.56108993), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(11.232691), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.72417235), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0065061487), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.2693216), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=13, seek=5998, start=np.float64(71.14), end=np.float64(73.14), text=' Ну, я понял, за сколько предложили снизить крат?', tokens=[50929, 7571, 11, 2552, 37975, 11, 4396, 28838, 40373, 5435, 776, 29951, 3258, 7502, 2134, 30, 51026], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' Ну,', start=np.float64(71.14), end=np.float64(71.58), probability=np.float64(0.7142734527587891)), WordMetrics(word=' я', start=np.float64(71.62), end=np.float64(71.7), probability=np.float64(0.6860554218292236)), WordMetrics(word=' понял,', start=np.float64(71.7), end=np.float64(71.8), probability=np.float64(0.9998536109924316)), WordMetrics(word=' за', start=np.float64(71.9), end=np.float64(72.06), probability=np.float64(0.9849435091018677)), WordMetrics(word=' сколько', start=np.float64(72.06), end=np.float64(72.22), probability=np.float64(0.9954743981361389)), WordMetrics(word=' предложили', start=np.float64(72.22), end=np.float64(72.68), probability=np.float64(0.9069143533706665)), WordMetrics(word=' снизить', start=np.float64(72.68), end=np.float64(72.9), probability=np.float64(0.7121238708496094)), WordMetrics(word=' крат?', start=np.float64(72.9), end=np.float64(73.14), probability=np.float64(0.8741057515144348))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5384855), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5251837), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7028266), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(39.009), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.91323185), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.085099086), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0016690667), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=14, seek=5998, start=np.float64(80.12), end=np.float64(80.56), text=' Угу.', tokens=[51377, 6523, 28264, 13, 51397], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' Угу.', start=np.float64(80.12), end=np.float64(80.56), probability=np.float64(0.9542238712310791))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.68844366), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6645001), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.8103735), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(34.252842), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9429926), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.032495447), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.024511872), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=15, seek=5998, start=np.float64(81.60000000000001), end=np.float64(82.04), text=' Угу.', tokens=[51456, 6523, 28264, 13, 51476], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' Угу.', start=np.float64(81.60000000000001), end=np.float64(82.04), probability=np.float64(0.8059675097465515))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.4164017), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.3723208), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.3644563), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(15.348866), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.8844488), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0033879902), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.11216311), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=16, seek=5998, start=np.float64(84.10000000000001), end=np.float64(84.54), text=' Понял.', tokens=[51575, 36067, 16065, 13, 51595], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' Понял.', start=np.float64(84.10000000000001), end=np.float64(84.54), probability=np.float64(0.9895193576812744))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.8261108), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7275818), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.49749207), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(19.648314), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.70495355), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.008079068), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.28696743), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=17, seek=5998, start=np.float64(84.94), end=np.float64(86.6), text=' На какую сумму сами рассчитываете?', tokens=[51632, 11245, 45244, 31372, 11147, 34085, 23345, 9607, 4655, 17670, 30, 51700], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' На', start=np.float64(84.94), end=np.float64(85.38), probability=np.float64(0.6103659272193909)), WordMetrics(word=' какую', start=np.float64(85.38), end=np.float64(85.6), probability=np.float64(0.9995167255401611)), WordMetrics(word=' сумму', start=np.float64(85.6), end=np.float64(85.98), probability=np.float64(0.9996367692947388)), WordMetrics(word=' сами', start=np.float64(85.98), end=np.float64(86.08), probability=np.float64(0.8241219520568848)), WordMetrics(word=' рассчитываете?', start=np.float64(86.08), end=np.float64(86.6), probability=np.float64(0.9967348724603653))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.74844635), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.630479), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.54108274), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(18.90711), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9687498), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0012252423), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.030024946), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=18, seek=5998, start=np.float64(86.72), end=np.float64(88.54), text=' И каким способом вообще планируете покупку?', tokens=[51712, 3272, 49190, 23677, 1253, 14345, 9283, 3733, 2711, 10524, 34005, 4401, 30, 51795], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' И', start=np.float64(86.72), end=np.float64(86.94), probability=np.float64(0.9929170608520508)), WordMetrics(word=' каким', start=np.float64(86.94), end=np.float64(87.16), probability=np.float64(0.9992856383323669)), WordMetrics(word=' способом', start=np.float64(87.16), end=np.float64(87.56), probability=np.float64(0.9959004819393158)), WordMetrics(word=' вообще', start=np.float64(87.56), end=np.float64(87.7), probability=np.float64(0.9883205890655518)), WordMetrics(word=' планируете', start=np.float64(87.7), end=np.float64(88.12), probability=np.float64(0.9993053525686264)), WordMetrics(word=' покупку?', start=np.float64(88.12), end=np.float64(88.54), probability=np.float64(0.9996814727783203))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7821918), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6711635), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6464539), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(20.509916), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9322509), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.013174638), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.05457451), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=19, seek=5998, start=np.float64(88.6), end=np.float64(89.7), text=' Там будет у вас кредит наличный?', tokens=[51795, 27451, 7306, 1595, 10655, 7502, 2229, 1635, 32750, 3903, 4441, 30, 51857], temperature=0.0, avg_logprob=-0.31167781663977584, compression_ratio=1.8267148014440433, no_speech_prob=0.017437146976590157, words=[WordMetrics(word=' Там', start=np.float64(88.6), end=np.float64(88.7), probability=np.float64(0.8113546371459961)), WordMetrics(word=' будет', start=np.float64(88.7), end=np.float64(88.86), probability=np.float64(0.9904189705848694)), WordMetrics(word=' у', start=np.float64(88.86), end=np.float64(88.92), probability=np.float64(0.900536060333252)), WordMetrics(word=' вас', start=np.float64(88.92), end=np.float64(89.02), probability=np.float64(0.9703870415687561)), WordMetrics(word=' кредит', start=np.float64(89.02), end=np.float64(89.32), probability=np.float64(0.8590526978174845)), WordMetrics(word=' наличный?', start=np.float64(89.32), end=np.float64(89.7), probability=np.float64(0.9555634458859762))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.57911307), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5785551), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6905524), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(36.983192), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9946502), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0033884994), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0019613046), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=21, seek=8970, start=np.float64(93.62), end=np.float64(94.18), text=' Угу.', tokens=[50567, 6523, 28264, 13, 50589], temperature=0.0, avg_logprob=-0.3872667067121751, compression_ratio=1.8248847926267282, no_speech_prob=0.049846161156892776, words=[WordMetrics(word=' Угу.', start=np.float64(93.62), end=np.float64(94.18), probability=np.float64(0.5618638247251511))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.84650826), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7239673), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.41553372), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(23.714851), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.94254297), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.010283919), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.047173012), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=22, seek=8970, start=np.float64(94.18), end=np.float64(96.48), text=' Ну, рассрочка, да, вам рассказали, там 60% износа.', tokens=[50601, 7571, 11, 23345, 481, 29576, 11, 8995, 11, 10448, 34760, 4071, 11, 8223, 4060, 4, 3943, 1234, 22568, 13, 50710], temperature=0.0, avg_logprob=-0.3872667067121751, compression_ratio=1.8248847926267282, no_speech_prob=0.049846161156892776, words=[WordMetrics(word=' Ну,', start=np.float64(94.18), end=np.float64(94.52), probability=np.float64(0.8014578223228455)), WordMetrics(word=' рассрочка,', start=np.float64(94.58), end=np.float64(94.86), probability=np.float64(0.8402865926424662)), WordMetrics(word=' да,', start=np.float64(94.86), end=np.float64(95.04), probability=np.float64(0.9461849331855774)), WordMetrics(word=' вам', start=np.float64(95.06), end=np.float64(95.12), probability=np.float64(0.8733912706375122)), WordMetrics(word=' рассказали,', start=np.float64(95.12), end=np.float64(95.52), probability=np.float64(0.9958259761333466)), WordMetrics(word=' там', start=np.float64(95.54), end=np.float64(95.64), probability=np.float64(0.9098175764083862)), WordMetrics(word=' 60', start=np.float64(95.64), end=np.float64(95.82), probability=np.float64(0.8102713227272034)), WordMetrics(word='%', start=np.float64(95.82), end=np.float64(96.14), probability=np.float64(0.9883076548576355)), WordMetrics(word=' износа.', start=np.float64(96.14), end=np.float64(96.48), probability=np.float64(0.7587763667106628))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.88773984), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.77014726), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.68492323), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(15.021494), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.28653282), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.025033718), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6884334), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=23, seek=8970, start=np.float64(99.44), end=np.float64(102.06), text=' 60% должно быть износно, 3 года рассрочка будет.', tokens=[50866, 4060, 4, 40475, 11510, 3943, 32472, 1234, 11, 805, 18411, 23345, 481, 29576, 7306, 13, 50989], temperature=0.0, avg_logprob=-0.3872667067121751, compression_ratio=1.8248847926267282, no_speech_prob=0.049846161156892776, words=[WordMetrics(word=' 60', start=np.float64(99.44), end=np.float64(100.0), probability=np.float64(0.9926504492759705)), WordMetrics(word='%', start=np.float64(100.0), end=np.float64(100.3), probability=np.float64(0.9996901750564575)), WordMetrics(word=' должно', start=np.float64(100.3), end=np.float64(100.64), probability=np.float64(0.9363548159599304)), WordMetrics(word=' быть', start=np.float64(100.64), end=np.float64(100.84), probability=np.float64(0.9919735193252563)), WordMetrics(word=' износно,', start=np.float64(100.84), end=np.float64(101.16), probability=np.float64(0.6619883080323538)), WordMetrics(word=' 3', start=np.float64(101.16), end=np.float64(101.28), probability=np.float64(0.7979586124420166)), WordMetrics(word=' года', start=np.float64(101.28), end=np.float64(101.44), probability=np.float64(0.9550477862358093)), WordMetrics(word=' рассрочка', start=np.float64(101.44), end=np.float64(101.86), probability=np.float64(0.9912211497624716)), WordMetrics(word=' будет.', start=np.float64(101.86), end=np.float64(102.06), probability=np.float64(0.9988941550254822))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.50713134), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.4608287), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.39745408), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(28.426977), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.86129016), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.13558224), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0031275374), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=24, seek=8970, start=np.float64(104.9), end=np.float64(105.46), text=' Угу.', tokens=[51135, 6523, 28264, 13, 51151], temperature=0.0, avg_logprob=-0.3872667067121751, compression_ratio=1.8248847926267282, no_speech_prob=0.049846161156892776, words=[WordMetrics(word=' Угу.', start=np.float64(104.9), end=np.float64(105.46), probability=np.float64(0.9485664963722229))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.35161445), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.32243246), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.32763073), unit=None, description=None)], description=None)},
# ...
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(26.322418), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9656323), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.015551747), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.018815974), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=77, seek=29940, start=np.float64(299.4), end=np.float64(300.4), text=' В трейдинге было 400, сейчас 350.', tokens=[50365, 2348, 7550, 2345, 856, 33177, 387, 8060, 8423, 11, 10241, 18065, 13, 50465], temperature=0.0, avg_logprob=-0.21381628616996434, compression_ratio=1.8561872909698998, no_speech_prob=0.009124301373958588, words=[WordMetrics(word=' В', start=np.float64(299.4), end=np.float64(299.44), probability=np.float64(0.01736810803413391)), WordMetrics(word=' трейдинге', start=np.float64(299.44), end=np.float64(299.44), probability=np.float64(0.5522192438598722)), WordMetrics(word=' было', start=np.float64(299.44), end=np.float64(299.44), probability=np.float64(0.06675311923027039)), WordMetrics(word=' 400,', start=np.float64(299.44), end=np.float64(299.72), probability=np.float64(0.7790365815162659)), WordMetrics(word=' сейчас', start=np.float64(299.88), end=np.float64(300.02), probability=np.float64(0.36021193861961365)), WordMetrics(word=' 350.', start=np.float64(300.02), end=np.float64(300.4), probability=np.float64(0.7550252676010132))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.86470824), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.762542), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.3613707), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(17.322817), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.77331185), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.02235535), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.20433278), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=78, seek=29940, start=np.float64(300.92), end=np.float64(304.72), text=' По сути, цена от автомобиля осталась той же самой, а автомобиль вырос на 50 тысяч рублей.', tokens=[50465, 12121, 18272, 3396, 11, 5188, 13362, 2943, 37122, 50211, 12574, 19711, 38509, 6151, 49560, 11, 2559, 37122, 7094, 2840, 9225, 1470, 2625, 25025, 40851, 13, 50665], temperature=0.0, avg_logprob=-0.21381628616996434, compression_ratio=1.8561872909698998, no_speech_prob=0.009124301373958588, words=[WordMetrics(word=' По', start=np.float64(300.92), end=np.float64(301.14), probability=np.float64(0.3451790511608124)), WordMetrics(word=' сути,', start=np.float64(301.14), end=np.float64(301.42), probability=np.float64(0.9964458048343658)), WordMetrics(word=' цена', start=np.float64(301.42), end=np.float64(301.62), probability=np.float64(0.9637430310249329)), WordMetrics(word=' от', start=np.float64(301.62), end=np.float64(301.7), probability=np.float64(0.2575772702693939)), WordMetrics(word=' автомобиля', start=np.float64(301.7), end=np.float64(302.1), probability=np.float64(0.9847593903541565)), WordMetrics(word=' осталась', start=np.float64(302.1), end=np.float64(302.36), probability=np.float64(0.9085533618927002)), WordMetrics(word=' той', start=np.float64(302.36), end=np.float64(302.52), probability=np.float64(0.3273385167121887)), WordMetrics(word=' же', start=np.float64(302.52), end=np.float64(302.64), probability=np.float64(0.9504716396331787)), WordMetrics(word=' самой,', start=np.float64(302.64), end=np.float64(302.92), probability=np.float64(0.9086922407150269)), WordMetrics(word=' а', start=np.float64(303.0), end=np.float64(303.34), probability=np.float64(0.859083354473114)), WordMetrics(word=' автомобиль', start=np.float64(303.34), end=np.float64(303.74), probability=np.float64(0.9331271350383759)), WordMetrics(word=' вырос', start=np.float64(303.74), end=np.float64(303.92), probability=np.float64(0.9904157817363739)), WordMetrics(word=' на', start=np.float64(303.92), end=np.float64(304.02), probability=np.float64(0.9849504232406616)), WordMetrics(word=' 50', start=np.float64(304.02), end=np.float64(304.2), probability=np.float64(0.7621757984161377)), WordMetrics(word=' тысяч', start=np.float64(304.2), end=np.float64(304.48), probability=np.float64(0.47853153944015503)), WordMetrics(word=' рублей.', start=np.float64(304.48), end=np.float64(304.72), probability=np.float64(0.9596390724182129))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.67285204), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6281443), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.31288475), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(27.261295), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.9951351), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0024495092), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0024153916), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=79, seek=29940, start=np.float64(305.18), end=np.float64(306.72), text=' То есть вот так вот из-за этого.', tokens=[50665, 16047, 5640, 5505, 2936, 5505, 3943, 12, 18598, 10751, 13, 50815], temperature=0.0, avg_logprob=-0.21381628616996434, compression_ratio=1.8561872909698998, no_speech_prob=0.009124301373958588, words=[WordMetrics(word=' То', start=np.float64(305.18), end=np.float64(305.18), probability=np.float64(0.8094170689582825)), WordMetrics(word=' есть', start=np.float64(305.18), end=np.float64(305.18), probability=np.float64(0.3087122440338135)), WordMetrics(word=' вот', start=np.float64(305.18), end=np.float64(305.34), probability=np.float64(0.5175217986106873)), WordMetrics(word=' так', start=np.float64(305.34), end=np.float64(305.46), probability=np.float64(0.6448312401771545)), WordMetrics(word=' вот', start=np.float64(305.46), end=np.float64(305.74), probability=np.float64(0.6416811347007751)), WordMetrics(word=' из', start=np.float64(305.74), end=np.float64(306.38), probability=np.float64(0.2765410542488098)), WordMetrics(word='-за', start=np.float64(306.38), end=np.float64(306.5), probability=np.float64(0.8958745002746582)), WordMetrics(word=' этого.', start=np.float64(306.5), end=np.float64(306.72), probability=np.float64(0.9954973459243774))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.7505022), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.67471737), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.4798486), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(18.312914), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.773593), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.002474159), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.22393285), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=80, seek=29940, start=np.float64(307.7), end=np.float64(312.76), text=' То же самое было в прошлом году, когда с 1 октября тоже все сборы начали повышать цены.', tokens=[50815, 16047, 6151, 25676, 8060, 740, 20567, 28209, 22688, 11, 8874, 776, 502, 11423, 35151, 1552, 22533, 12251, 4640, 29014, 42342, 8970, 4071, 10499, 12533, 2209, 5188, 16148, 13, 51065], temperature=0.0, avg_logprob=-0.21381628616996434, compression_ratio=1.8561872909698998, no_speech_prob=0.009124301373958588, words=[WordMetrics(word=' То', start=np.float64(307.7), end=np.float64(308.18), probability=np.float64(0.8786280155181885)), WordMetrics(word=' же', start=np.float64(308.18), end=np.float64(308.28), probability=np.float64(0.9974130988121033)), WordMetrics(word=' самое', start=np.float64(308.28), end=np.float64(308.5), probability=np.float64(0.9967328310012817)), WordMetrics(word=' было', start=np.float64(308.5), end=np.float64(308.78), probability=np.float64(0.9933894872665405)), WordMetrics(word=' в', start=np.float64(308.78), end=np.float64(308.9), probability=np.float64(0.9745902419090271)), WordMetrics(word=' прошлом', start=np.float64(308.9), end=np.float64(309.16), probability=np.float64(0.9984565675258636)), WordMetrics(word=' году,', start=np.float64(309.16), end=np.float64(309.36), probability=np.float64(0.9983793497085571)), WordMetrics(word=' когда', start=np.float64(309.46), end=np.float64(309.66), probability=np.float64(0.9843563437461853)), WordMetrics(word=' с', start=np.float64(309.66), end=np.float64(309.98), probability=np.float64(0.6771160364151001)), WordMetrics(word=' 1', start=np.float64(309.98), end=np.float64(310.26), probability=np.float64(0.8791788816452026)), WordMetrics(word=' октября', start=np.float64(310.26), end=np.float64(310.88), probability=np.float64(0.9935530126094818)), WordMetrics(word=' тоже', start=np.float64(310.88), end=np.float64(311.46), probability=np.float64(0.3763233721256256)), WordMetrics(word=' все', start=np.float64(311.46), end=np.float64(311.66), probability=np.float64(0.04173930734395981)), WordMetrics(word=' сборы', start=np.float64(311.66), end=np.float64(311.96), probability=np.float64(0.8095389306545258)), WordMetrics(word=' начали', start=np.float64(311.96), end=np.float64(312.18), probability=np.float64(0.8616854846477509)), WordMetrics(word=' повышать', start=np.float64(312.18), end=np.float64(312.56), probability=np.float64(0.7980173130830129)), WordMetrics(word=' цены.', start=np.float64(312.56), end=np.float64(312.76), probability=np.float64(0.6723409593105316))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.83511496), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.69954294), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.5125136), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(28.009388), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.99628997), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0025695683), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0011405027), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=81, seek=29940, start=np.float64(312.76), end=np.float64(314.86), text=' Уже не сразу на 10% повысил цены.', tokens=[51065, 6523, 4757, 1725, 22014, 1470, 1266, 4, 10499, 29476, 2338, 5188, 16148, 13, 51215], temperature=0.0, avg_logprob=-0.21381628616996434, compression_ratio=1.8561872909698998, no_speech_prob=0.009124301373958588, words=[WordMetrics(word=' Уже', start=np.float64(312.76), end=np.float64(313.0), probability=np.float64(0.6887824982404709)), WordMetrics(word=' не', start=np.float64(313.0), end=np.float64(313.12), probability=np.float64(0.9867985844612122)), WordMetrics(word=' сразу', start=np.float64(313.12), end=np.float64(313.36), probability=np.float64(0.9943607449531555)), WordMetrics(word=' на', start=np.float64(313.36), end=np.float64(313.56), probability=np.float64(0.9540612101554871)), WordMetrics(word=' 10', start=np.float64(313.56), end=np.float64(313.74), probability=np.float64(0.9885349869728088)), WordMetrics(word='%', start=np.float64(313.74), end=np.float64(314.08), probability=np.float64(0.7478713393211365)), WordMetrics(word=' повысил', start=np.float64(314.08), end=np.float64(314.56), probability=np.float64(0.8960148692131042)), WordMetrics(word=' цены.', start=np.float64(314.56), end=np.float64(314.86), probability=np.float64(0.9870540201663971))])),
#  ({'emotion': MetricCollection(provider='audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim', metrics=[Metric(name='arousal', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.76395714), unit=None, description=None), Metric(name='dominance', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.72322094), unit=None, description=None), Metric(name='valence', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.6094932), unit=None, description=None)], description=None)},
#   {'age_gender': MetricCollection(provider='audeering/wav2vec2-large-robust-6-ft-age-gender', metrics=[Metric(name='age', type=<MetricType.INT: 'int'>, value=np.float32(32.47858), unit='years', description=None), Metric(name='female', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.95254374), unit=None, description=None), Metric(name='male', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.04010376), unit=None, description=None), Metric(name='child', type=<MetricType.FLOAT: 'float'>, value=np.float32(0.0073525207), unit=None, description=None)], description=None)},
#   WhisperMetrics(id=82, seek=29940, start=np.float64(315.8), end=np.float64(317.84), text=' Там была скидка по семейной процентной.', tokens=[51215, 27451, 13640, 776, 2241, 856, 2833, 2801, 20933, 2345, 5007, 20640, 5243, 5007, 13, 51315], temperature=0.0, avg_logprob=-0.21381628616996434, compression_ratio=1.8561872909698998, no_speech_prob=0.009124301373958588, words=[WordMetrics(word=' Там', start=np.float64(315.8), end=np.float64(316.28), probability=np.float64(0.9877279996871948)), WordMetrics(word=' была', start=np.float64(316.28), end=np.float64(316.54), probability=np.float64(0.9956355690956116)), WordMetrics(word=' скидка', start=np.float64(316.54), end=np.float64(316.98), probability=np.float64(0.9753163456916809)), WordMetrics(word=' по', start=np.float64(316.98), end=np.float64(317.06), probability=np.float64(0.9624952673912048)), WordMetrics(word=' семейной', start=np.float64(317.06), end=np.float64(317.5), probability=np.float64(0.8060482442378998)), WordMetrics(word=' процентной.', start=np.float64(317.5), end=np.float64(317.84), probability=np.float64(0.41628052045901615))]))]
