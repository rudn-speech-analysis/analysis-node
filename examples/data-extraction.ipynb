# %%
import torch

# %%
if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
    for i in range(num_gpus):
        gpu_name = torch.cuda.get_device_name(i)
        print(f"GPU {i}: {gpu_name}")
else:
    print("CUDA is not available.")
# Out:
# GPU 0: AMD Radeon RX 9070 XT
# GPU 1: AMD Ryzen 7 7800X3D 8-Core Processor

# %%
DEVICE="cuda:0"

# %%
DATASET_DIR = "../dataset"

ORIG_FILE = "./output/original.wav"
SPEAKER1_FILE = "./output/speaker1.wav"
SPEAKER2_FILE = "./output/speaker2.wav"
SPEAKER1_METRICS_FILE = "./output/speaker1.json"
SPEAKER2_METRICS_FILE = "./output/speaker2.json"

SPEAKER1_DIR = "./output/speaker1"
SPEAKER2_DIR = "./output/speaker2"

MIN_SEGMENT_LENGTH_SEC = 0.1
STOP_PHRASES = [
    "ДИНАМИЧНАЯ МУЗЫКА",
    "Продолжение следует.",
    "Продолжение следует...",
]
STOP_PHRASE_LENGTH_DELTA = 5

PER_PHRASE_METRICS = []
PER_PHRASE_METRIC_NAMES = ["whisper"]
PER_RECORDING_METRICS = []
PER_RECORDING_METRIC_NAMES = []

# %%
def per_phrase(func):
    PER_PHRASE_METRICS.append(func)
    PER_PHRASE_METRIC_NAMES.append(func.__name__)
    
def per_recording(func):
    PER_RECORDING_METRICS.append(func)
    PER_RECORDING_METRIC_NAMES.append(func.__name__)

# %%
import os

os.makedirs(SPEAKER1_DIR, exist_ok=True)
os.makedirs(SPEAKER2_DIR, exist_ok=True)

# %%
import random

input_file = random.choice(os.listdir(DATASET_DIR))
input_file = f"{DATASET_DIR}/" + input_file
input_file
# Out:
# '../dataset/mix_13053_16e012__2025_10_01__09_25_43_960.mp3'

# %%
import pydub

audio = pydub.AudioSegment.from_file(input_file)

try:
    left_channel, right_channel = audio.split_to_mono()
except ValueError as ex:
    raise ValueError("Input file must be stereo.") from ex

left_channel.export(SPEAKER1_FILE, format="wav")
right_channel.export(SPEAKER2_FILE, format="wav")
audio.export(ORIG_FILE, format="wav")
# Out:
# <_io.BufferedRandom name='./output/original.wav'>

# %%
import whisper
whispermodel = whisper.load_model("large").to(DEVICE)

# %%
from typing import Generator, Tuple

def filter_out(segment_data: dict) -> bool:
    # Removing short segments
    if (segment_data["end"] - segment_data["start"]) < MIN_SEGMENT_LENGTH_SEC:
        return True

    # Removing segments that contain stop_phrases
    matching_stop_phrases = [s for s in STOP_PHRASES if s.lower() in segment_data["text"].lower()]
    if matching_stop_phrases:
        # Remove the segment if it contains only a stop phrase
        if max(map(len, matching_stop_phrases)) + STOP_PHRASE_LENGTH_DELTA > len(segment_data["text"].strip()):
            return True
            
    return False

def segmentize(source: str, segments_dir: str) -> Generator[Tuple[dict, str]]:
    transcription = whispermodel.transcribe(source, word_timestamps=True, language='ru')
    audio = pydub.AudioSegment.from_file(source)
    for segment_data in transcription['segments']:
        if filter_out(segment_data):
            continue
        start = float(segment_data['start']) * 1000
        end = float(segment_data['end']) * 1000
        path = f"{segments_dir}/{segment_data['id']}.wav"
        audio[start:end].export(path, format="wav")
        yield (segment_data, path)

# %%
def show(vals: dict) -> dict:
    keys = ["id", "start", "end", "text"]
    return {k: vals[0][k] for k in keys}
list(map(show, segmentize(SPEAKER1_FILE, SPEAKER1_DIR)))
# Out:
# [{'id': 0,
#   'start': np.float64(0.0),
#   'end': np.float64(6.34),
#   'text': ' Добрый день, меня зовут Вадим, я представляю Автомир, официального дилера ХВЛ.'},
#  {'id': 1,
#   'start': np.float64(6.54),
#   'end': np.float64(10.16),
#   'text': ' Вы планируете покупку нового автомобиля ХВЛ в Самаре в ближайший месяц?'},
#  {'id': 2,
#   'start': np.float64(15.08),
#   'end': np.float64(17.28),
#   'text': ' Скажите, какая модель вас интересует?'},
#  {'id': 3,
#   'start': np.float64(22.06),
#   'end': np.float64(23.68),
#   'text': ' F7 или H7?'},
#  {'id': 4,
#   'start': np.float64(25.62),
#   'end': np.float64(26.42),
#   'text': ' F7?'},
#  {'id': 5,
#   'start': np.float64(28.860000000000003),
#   'end': np.float64(32.04),
#   'text': ' А покупку планируете как физическое или как юридическое лицо?'},
#  {'id': 6,
#   'start': np.float64(36.06),
#   'end': np.float64(40.88),
#   'text': ' Тогда давайте я прямо сейчас соединю вас с менеджером, который подберет предложение по вашим параметрам.'},
#  {'id': 7,
#   'start': np.float64(41.0),
#   'end': np.float64(42.24),
#   'text': ' Как могу вас представить?'},
#  {'id': 8,
#   'start': np.float64(44.52),
#   'end': np.float64(48.3),
#   'text': ' Александр, очень приятно. Скажите, Александр, есть ли условия все устроят?'},
#  {'id': 9,
#   'start': np.float64(48.34),
#   'end': np.float64(51.14),
#   'text': ' Вы готовы рассмотреть покупку автомобиля в ближайшие 30 дней?'},
#  {'id': 10,
#   'start': np.float64(53.660000000000004),
#   'end': np.float64(56.4),
#   'text': ' А хорошо, тогда не кладите трубку, прямо сейчас соединяюсь.'},
#  {'id': 11,
#   'start': np.float64(56.42),
#   'end': np.float64(56.78),
#   'text': ' Спасибо, менеджер.'}]

# %%
from typing import Callable, Any

def collect_metrics_for_segment(
    source: str,
    phrase_model_callbacks: list[Callable[[str], dict[str, Any]]],
    recording_model_callbacks: list[Callable[[str], dict[str, Any]]],
) -> dict[str, dict]:
    return (
        {model.__name__: model(source) for model in phrase_model_callbacks},
        {model.__name__: model(source) for model in recording_model_callbacks},
    )

def collect_metrics(
    source: str,
    segments_dir: str,
    phrase_model_callbacks: list[Callable[[str], dict[str, Any]]],
    recording_model_callbacks: list[Callable[[str], dict[str, Any]]],
) -> Generator[dict[str, dict[str, Any]]]:
    for segment_data, x in segmentize(source, segments_dir):
        text = segment_data["text"]
        print(segment_data["id"], f"[{text}]")
        (per_phrase, per_recording) = collect_metrics_for_segment(x, phrase_model_callbacks, recording_model_callbacks)
        yield (per_phrase | dict(whisper=segment_data), per_recording)

# %%
from funasr import AutoModel

# model="iic/emotion2vec_base"
# model="iic/emotion2vec_base_finetuned"
# model="iic/emotion2vec_plus_seed"
# model="iic/emotion2vec_plus_base"
model_id = "iic/emotion2vec_plus_large"

emomodel = AutoModel(
    model=model_id,
    hub="hf",
    disable_update=True,
    device=DEVICE,
    log_level="CRITICAL",
)

_ = emomodel.model.to(DEVICE)
# Out:
# funasr version: 1.2.7.
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.0.0.weight, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.0.0.bias, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.1.0.weight, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.1.0.bias, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.2.0.weight, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.2.0.bias, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.3.0.weight, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.blocks.3.0.bias, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.proj.weight, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt
# Warning, miss key in ckpt: modality_encoders.AUDIO.decoder.proj.bias, /home/gmatiukhin/.cache/huggingface/hub/models--emotion2vec--emotion2vec_plus_large/snapshots/6c303ba987b86b93193de93e34bb2b077a6bedc4/model.pt

# %%
@per_phrase
def emotion2vec(segment_path: str) -> dict[str, Any]:
    out = emomodel.generate(segment_path, granularity="utterance", extract_embedding=False)
    return {k.split("/")[-1]: v for (k, v) in zip(out[0]["labels"], out[0]["scores"])}

# %%
from analysis_node.analysis import EmotionPipeline

emotion_pipeline = EmotionPipeline(DEVICE)

# %%
from scipy.io import wavfile

@per_phrase
def wav2vec2_emotion(segment_file: str) -> dict[str, Any]:
    sample_rate, waveform = wavfile.read(segment_file)
    vals = emotion_pipeline(waveform, sample_rate)
    return {k: v for (k, v) in zip(["arousal", "dominance", "valence"], vals[0])}

# %%
from analysis_node.analysis import AgeGenderPipeline

age_gender_pipeline = AgeGenderPipeline("small", DEVICE)

# %%
@per_recording
def wav2vec2_age_gender(segment_file: str) -> dict[str, Any]:
    sample_rate, waveform = wavfile.read(segment_file)
    vals = age_gender_pipeline(waveform, sample_rate)
    out = {k: v for (k, v) in zip(["age", "female", "male", "child"], vals[0])}
    return out

# %%
raw_metrics = list(collect_metrics(SPEAKER1_FILE, SPEAKER1_DIR, PER_PHRASE_METRICS, PER_RECORDING_METRICS))
raw_metrics
# Out:
# 0 [ Добрый день, меня зовут Вадим, я представляю Автомир, официального дилера ХВЛ.]
# rtf_avg: 0.018: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# 1 [ Вы планируете покупку нового автомобиля ХВЛ в Самаре в ближайший месяц?]
# rtf_avg: 0.016: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 17.10it/s]
# 2 [ Скажите, какая модель вас интересует?]
# rtf_avg: 0.041: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.83it/s]
# 3 [ F7 или H7?]
# rtf_avg: 0.026: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.88it/s]
# 4 [ F7?]
# rtf_avg: 0.038: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 32.28it/s]
# 5 [ А покупку планируете как физическое или как юридическое лицо?]
# rtf_avg: 0.255: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.23it/s]
# 6 [ Тогда давайте я прямо сейчас соединю вас с менеджером, который подберет предложение по вашим параметрам.]
# rtf_avg: 0.244: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.18s/it]
# 7 [ Как могу вас представить?]
# rtf_avg: 0.034: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 23.17it/s]
# 8 [ Александр, очень приятно. Скажите, Александр, есть ли условия все устроят?]
# rtf_avg: 0.249: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.06it/s]
# 9 [ Вы готовы рассмотреть покупку автомобиля в ближайшие 30 дней?]
# rtf_avg: 0.018: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 19.18it/s]
# 10 [ А хорошо, тогда не кладите трубку, прямо сейчас соединяюсь.]
# rtf_avg: 0.267: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.36it/s]
# 11 [ Спасибо, менеджер.]
# rtf_avg: 0.086: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 31.47it/s]
# [({'emotion2vec': {'angry': 3.7985137169016525e-05,
#     'disgusted': 0.00010294616367900744,
#     'fearful': 0.0001235693198395893,
#     'happy': 0.002397349802777171,
#     'neutral': 0.9833465814590454,
#     'other': 8.582897862652317e-05,
#     'sad': 0.0006209969869814813,
#     'surprised': 1.0889703844441101e-05,
#     '<unk>': 0.013273905962705612},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7356798),
#     'dominance': np.float32(0.6685522),
#     'valence': np.float32(0.3694641)},
#    'whisper': {'id': 0,
#     'seek': 0,
#     'start': np.float64(0.0),
#     'end': np.float64(6.34),
#     'text': ' Добрый день, меня зовут Вадим, я представляю Автомир, официального дилера ХВЛ.',
#     'tokens': [50365,
#      3401,
#      13829,
#      4851,
#      13509,
#      11,
#      6885,
#      46376,
#      2348,
#      2601,
#      2165,
#      11,
#      2552,
#      39412,
#      1148,
#      50175,
#      17804,
#      4490,
#      11,
#      31950,
#      30321,
#      31227,
#      1070,
#      2338,
#      13126,
#      9456,
#      8578,
#      14854,
#      13,
#      50691],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' Добрый',
#       'start': np.float64(0.0),
#       'end': np.float64(1.24),
#       'probability': np.float64(0.7450953722000122)},
#      {'word': ' день,',
#       'start': np.float64(1.24),
#       'end': np.float64(1.36),
#       'probability': np.float64(0.9973821043968201)},
#      {'word': ' меня',
#       'start': np.float64(1.46),
#       'end': np.float64(2.74),
#       'probability': np.float64(0.8405876755714417)},
#      {'word': ' зовут',
#       'start': np.float64(2.74),
#       'end': np.float64(3.04),
#       'probability': np.float64(0.9977419376373291)},
#      {'word': ' Вадим,',
#       'start': np.float64(3.04),
#       'end': np.float64(3.46),
#       'probability': np.float64(0.9954708019892374)},
#      {'word': ' я',
#       'start': np.float64(3.46),
#       'end': np.float64(3.8),
#       'probability': np.float64(0.9797195792198181)},
#      {'word': ' представляю',
#       'start': np.float64(3.8),
#       'end': np.float64(4.4),
#       'probability': np.float64(0.9754282236099243)},
#      {'word': ' Автомир,',
#       'start': np.float64(4.4),
#       'end': np.float64(4.96),
#       'probability': np.float64(0.8010528087615967)},
#      {'word': ' официального',
#       'start': np.float64(5.0),
#       'end': np.float64(5.46),
#       'probability': np.float64(0.869212826093038)},
#      {'word': ' дилера',
#       'start': np.float64(5.46),
#       'end': np.float64(5.94),
#       'probability': np.float64(0.9953171412150065)},
#      {'word': ' ХВЛ.',
#       'start': np.float64(5.94),
#       'end': np.float64(6.34),
#       'probability': np.float64(0.5703746279080709)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.37956467),
#     'female': np.float32(0.9739237),
#     'male': np.float32(0.025317483),
#     'child': np.float32(0.00075878075)}}),
#  ({'emotion2vec': {'angry': 3.191628081822273e-07,
#     'disgusted': 5.845498662893078e-07,
#     'fearful': 7.850135261833202e-07,
#     'happy': 1.3677405149792321e-05,
#     'neutral': 0.9999760389328003,
#     'other': 3.079767623148655e-07,
#     'sad': 4.081447968928842e-06,
#     'surprised': 4.472383707820882e-08,
#     '<unk>': 4.036787686345633e-06},
#    'wav2vec2_emotion': {'arousal': np.float32(0.6963425),
#     'dominance': np.float32(0.6634601),
#     'valence': np.float32(0.48574674)},
#    'whisper': {'id': 1,
#     'seek': 0,
#     'start': np.float64(6.54),
#     'end': np.float64(10.16),
#     'text': ' Вы планируете покупку нового автомобиля ХВЛ в Самаре в ближайший месяц?',
#     'tokens': [50705,
#      11886,
#      9283,
#      3733,
#      2711,
#      10524,
#      34005,
#      4401,
#      10022,
#      2350,
#      37122,
#      50211,
#      9456,
#      8578,
#      14854,
#      740,
#      31152,
#      2222,
#      387,
#      740,
#      21747,
#      1820,
#      3183,
#      24958,
#      29329,
#      1814,
#      30,
#      50882],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' Вы',
#       'start': np.float64(6.54),
#       'end': np.float64(6.84),
#       'probability': np.float64(0.9991627931594849)},
#      {'word': ' планируете',
#       'start': np.float64(6.84),
#       'end': np.float64(7.32),
#       'probability': np.float64(0.9998561590909958)},
#      {'word': ' покупку',
#       'start': np.float64(7.32),
#       'end': np.float64(7.8),
#       'probability': np.float64(0.9995855093002319)},
#      {'word': ' нового',
#       'start': np.float64(7.8),
#       'end': np.float64(8.02),
#       'probability': np.float64(0.9989623725414276)},
#      {'word': ' автомобиля',
#       'start': np.float64(8.02),
#       'end': np.float64(8.44),
#       'probability': np.float64(0.9783834517002106)},
#      {'word': ' ХВЛ',
#       'start': np.float64(8.44),
#       'end': np.float64(8.82),
#       'probability': np.float64(0.9985711574554443)},
#      {'word': ' в',
#       'start': np.float64(8.82),
#       'end': np.float64(9.02),
#       'probability': np.float64(0.9996521472930908)},
#      {'word': ' Самаре',
#       'start': np.float64(9.02),
#       'end': np.float64(9.36),
#       'probability': np.float64(0.9987807869911194)},
#      {'word': ' в',
#       'start': np.float64(9.36),
#       'end': np.float64(9.42),
#       'probability': np.float64(0.9927818775177002)},
#      {'word': ' ближайший',
#       'start': np.float64(9.42),
#       'end': np.float64(9.74),
#       'probability': np.float64(0.9056216776371002)},
#      {'word': ' месяц?',
#       'start': np.float64(9.74),
#       'end': np.float64(10.16),
#       'probability': np.float64(0.9997113347053528)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.10216771),
#     'female': np.float32(0.83413625),
#     'male': np.float32(0.005244671),
#     'child': np.float32(0.16061911)}}),
#  ({'emotion2vec': {'angry': 1.4713505152030848e-05,
#     'disgusted': 2.929203947132919e-05,
#     'fearful': 3.29303766193334e-05,
#     'happy': 0.00225819437764585,
#     'neutral': 0.9960667490959167,
#     'other': 7.336878837804761e-08,
#     'sad': 0.0011225345078855753,
#     'surprised': 0.000475504610221833,
#     '<unk>': 4.698206712561159e-09},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7288242),
#     'dominance': np.float32(0.6378156),
#     'valence': np.float32(0.601018)},
#    'whisper': {'id': 2,
#     'seek': 0,
#     'start': np.float64(15.08),
#     'end': np.float64(17.28),
#     'text': ' Скажите, какая модель вас интересует?',
#     'tokens': [51123,
#      22965,
#      3234,
#      5878,
#      11,
#      29334,
#      24104,
#      3908,
#      10655,
#      15033,
#      17781,
#      30,
#      51236],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' Скажите,',
#       'start': np.float64(15.08),
#       'end': np.float64(15.88),
#       'probability': np.float64(0.9521047671635946)},
#      {'word': ' какая',
#       'start': np.float64(15.88),
#       'end': np.float64(16.08),
#       'probability': np.float64(0.9999152421951294)},
#      {'word': ' модель',
#       'start': np.float64(16.08),
#       'end': np.float64(16.48),
#       'probability': np.float64(0.9999237656593323)},
#      {'word': ' вас',
#       'start': np.float64(16.48),
#       'end': np.float64(16.62),
#       'probability': np.float64(0.8566867113113403)},
#      {'word': ' интересует?',
#       'start': np.float64(16.62),
#       'end': np.float64(17.28),
#       'probability': np.float64(0.9999722838401794)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.22870255),
#     'female': np.float32(0.24131215),
#     'male': np.float32(0.01501856),
#     'child': np.float32(0.7436693)}}),
#  ({'emotion2vec': {'angry': 0.00016556431364733726,
#     'disgusted': 0.0010418196907266974,
#     'fearful': 0.00031519183539785445,
#     'happy': 0.02753724530339241,
#     'neutral': 0.9685339331626892,
#     'other': 0.00010792788089020178,
#     'sad': 0.0009069611551240087,
#     'surprised': 0.0002124914899468422,
#     '<unk>': 0.0011789770796895027},
#    'wav2vec2_emotion': {'arousal': np.float32(0.6523959),
#     'dominance': np.float32(0.56699634),
#     'valence': np.float32(0.4112126)},
#    'whisper': {'id': 3,
#     'seek': 0,
#     'start': np.float64(22.06),
#     'end': np.float64(23.68),
#     'text': ' F7 или H7?',
#     'tokens': [51474, 479, 22, 8101, 389, 22, 30, 51558],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' F7',
#       'start': np.float64(22.06),
#       'end': np.float64(22.86),
#       'probability': np.float64(0.9442199170589447)},
#      {'word': ' или',
#       'start': np.float64(22.86),
#       'end': np.float64(23.04),
#       'probability': np.float64(0.9793375730514526)},
#      {'word': ' H7?',
#       'start': np.float64(23.04),
#       'end': np.float64(23.68),
#       'probability': np.float64(0.9993142187595367)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.4011107),
#     'female': np.float32(0.94969386),
#     'male': np.float32(0.049423236),
#     'child': np.float32(0.00088293845)}}),
#  ({'emotion2vec': {'angry': 0.00011868292494909838,
#     'disgusted': 0.00017413331079296768,
#     'fearful': 0.0001662678987486288,
#     'happy': 0.8755322098731995,
#     'neutral': 0.014197878539562225,
#     'other': 2.12881037242596e-08,
#     'sad': 0.0006305084680207074,
#     'surprised': 0.10918023437261581,
#     '<unk>': 1.0591821819616598e-07},
#    'wav2vec2_emotion': {'arousal': np.float32(0.6402663),
#     'dominance': np.float32(0.56835485),
#     'valence': np.float32(0.33883637)},
#    'whisper': {'id': 4,
#     'seek': 0,
#     'start': np.float64(25.62),
#     'end': np.float64(26.42),
#     'text': ' F7?',
#     'tokens': [51655, 479, 22, 30, 51695],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' F7?',
#       'start': np.float64(25.62),
#       'end': np.float64(26.42),
#       'probability': np.float64(0.985101044178009)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.3288244),
#     'female': np.float32(0.94889635),
#     'male': np.float32(0.04873967),
#     'child': np.float32(0.002364038)}}),
#  ({'emotion2vec': {'angry': 0.0005239499150775373,
#     'disgusted': 0.0011846543056890368,
#     'fearful': 0.0018442034488543868,
#     'happy': 0.7580862641334534,
#     'neutral': 0.18431128561496735,
#     'other': 0.004760020412504673,
#     'sad': 0.010309253819286823,
#     'surprised': 0.00013269041664898396,
#     '<unk>': 0.038847655057907104},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7595975),
#     'dominance': np.float32(0.6692323),
#     'valence': np.float32(0.5013543)},
#    'whisper': {'id': 5,
#     'seek': 2642,
#     'start': np.float64(28.860000000000003),
#     'end': np.float64(32.04),
#     'text': ' А покупку планируете как физическое или как юридическое лицо?',
#     'tokens': [50365,
#      3450,
#      34005,
#      4401,
#      9283,
#      3733,
#      2711,
#      10524,
#      3014,
#      44662,
#      9347,
#      22128,
#      8101,
#      3014,
#      29488,
#      481,
#      3586,
#      9347,
#      22128,
#      7444,
#      44569,
#      30,
#      50654],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' А',
#       'start': np.float64(28.860000000000003),
#       'end': np.float64(29.400000000000002),
#       'probability': np.float64(0.12866728007793427)},
#      {'word': ' покупку',
#       'start': np.float64(29.400000000000002),
#       'end': np.float64(29.94),
#       'probability': np.float64(0.8625057935714722)},
#      {'word': ' планируете',
#       'start': np.float64(29.94),
#       'end': np.float64(30.38),
#       'probability': np.float64(0.9567026495933533)},
#      {'word': ' как',
#       'start': np.float64(30.38),
#       'end': np.float64(30.54),
#       'probability': np.float64(0.9871406555175781)},
#      {'word': ' физическое',
#       'start': np.float64(30.54),
#       'end': np.float64(31.04),
#       'probability': np.float64(0.9959108233451843)},
#      {'word': ' или',
#       'start': np.float64(31.04),
#       'end': np.float64(31.14),
#       'probability': np.float64(0.9524978995323181)},
#      {'word': ' как',
#       'start': np.float64(31.14),
#       'end': np.float64(31.28),
#       'probability': np.float64(0.9640295505523682)},
#      {'word': ' юридическое',
#       'start': np.float64(31.28),
#       'end': np.float64(31.86),
#       'probability': np.float64(0.9990940690040588)},
#      {'word': ' лицо?',
#       'start': np.float64(31.86),
#       'end': np.float64(32.04),
#       'probability': np.float64(0.9456607103347778)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.18670866),
#     'female': np.float32(0.4169137),
#     'male': np.float32(0.006632591),
#     'child': np.float32(0.57645375)}}),
#  ({'emotion2vec': {'angry': 2.3686850909143686e-05,
#     'disgusted': 6.189792475197464e-05,
#     'fearful': 5.8695051848189905e-05,
#     'happy': 0.009599989280104637,
#     'neutral': 0.9895317554473877,
#     'other': 9.025319013744593e-05,
#     'sad': 0.00035178798134438694,
#     'surprised': 4.672315753850853e-06,
#     '<unk>': 0.0002772207953967154},
#    'wav2vec2_emotion': {'arousal': np.float32(0.8439917),
#     'dominance': np.float32(0.75498277),
#     'valence': np.float32(0.42179906)},
#    'whisper': {'id': 6,
#     'seek': 2642,
#     'start': np.float64(36.06),
#     'end': np.float64(40.88),
#     'text': ' Тогда давайте я прямо сейчас соединю вас с менеджером, который подберет предложение по вашим параметрам.',
#     'tokens': [50857,
#      46357,
#      30412,
#      2552,
#      28547,
#      10241,
#      7425,
#      30741,
#      1148,
#      10655,
#      776,
#      6046,
#      2229,
#      1820,
#      33370,
#      11,
#      11897,
#      4095,
#      1552,
#      1135,
#      1094,
#      40373,
#      5627,
#      2801,
#      14536,
#      2165,
#      11813,
#      1685,
#      1094,
#      15837,
#      13,
#      51094],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Тогда',
#       'start': np.float64(36.06),
#       'end': np.float64(36.6),
#       'probability': np.float64(0.5114366412162781)},
#      {'word': ' давайте',
#       'start': np.float64(36.6),
#       'end': np.float64(37.06),
#       'probability': np.float64(0.9902661442756653)},
#      {'word': ' я',
#       'start': np.float64(37.06),
#       'end': np.float64(37.26),
#       'probability': np.float64(0.9984096884727478)},
#      {'word': ' прямо',
#       'start': np.float64(37.26),
#       'end': np.float64(37.38),
#       'probability': np.float64(0.9473075270652771)},
#      {'word': ' сейчас',
#       'start': np.float64(37.38),
#       'end': np.float64(37.62),
#       'probability': np.float64(0.9997419714927673)},
#      {'word': ' соединю',
#       'start': np.float64(37.62),
#       'end': np.float64(38.02),
#       'probability': np.float64(0.9596470395723978)},
#      {'word': ' вас',
#       'start': np.float64(38.02),
#       'end': np.float64(38.24),
#       'probability': np.float64(0.9489714503288269)},
#      {'word': ' с',
#       'start': np.float64(38.24),
#       'end': np.float64(38.36),
#       'probability': np.float64(0.998415470123291)},
#      {'word': ' менеджером,',
#       'start': np.float64(38.36),
#       'end': np.float64(38.7),
#       'probability': np.float64(0.99949149787426)},
#      {'word': ' который',
#       'start': np.float64(38.72),
#       'end': np.float64(38.92),
#       'probability': np.float64(0.9991275668144226)},
#      {'word': ' подберет',
#       'start': np.float64(38.92),
#       'end': np.float64(39.34),
#       'probability': np.float64(0.9982127547264099)},
#      {'word': ' предложение',
#       'start': np.float64(39.34),
#       'end': np.float64(39.92),
#       'probability': np.float64(0.9946097731590271)},
#      {'word': ' по',
#       'start': np.float64(39.92),
#       'end': np.float64(40.08),
#       'probability': np.float64(0.999721109867096)},
#      {'word': ' вашим',
#       'start': np.float64(40.08),
#       'end': np.float64(40.44),
#       'probability': np.float64(0.9982703328132629)},
#      {'word': ' параметрам.',
#       'start': np.float64(40.44),
#       'end': np.float64(40.88),
#       'probability': np.float64(0.999767616391182)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.23377769),
#     'female': np.float32(0.61399364),
#     'male': np.float32(0.04149509),
#     'child': np.float32(0.34451124)}}),
#  ({'emotion2vec': {'angry': 7.897557225078344e-05,
#     'disgusted': 0.00010565540287643671,
#     'fearful': 9.837070683715865e-05,
#     'happy': 0.0005510866176337004,
#     'neutral': 0.9970014691352844,
#     'other': 5.352133598535147e-07,
#     'sad': 0.0014683923218399286,
#     'surprised': 0.0006943087209947407,
#     '<unk>': 1.2786388197127962e-06},
#    'wav2vec2_emotion': {'arousal': np.float32(0.682087),
#     'dominance': np.float32(0.60564756),
#     'valence': np.float32(0.46296152)},
#    'whisper': {'id': 7,
#     'seek': 2642,
#     'start': np.float64(41.0),
#     'end': np.float64(42.24),
#     'text': ' Как могу вас представить?',
#     'tokens': [51105, 11011, 22951, 10655, 27167, 3258, 30, 51162],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Как',
#       'start': np.float64(41.0),
#       'end': np.float64(41.26),
#       'probability': np.float64(0.9964990615844727)},
#      {'word': ' могу',
#       'start': np.float64(41.26),
#       'end': np.float64(41.5),
#       'probability': np.float64(0.997516393661499)},
#      {'word': ' вас',
#       'start': np.float64(41.5),
#       'end': np.float64(41.68),
#       'probability': np.float64(0.9966896772384644)},
#      {'word': ' представить?',
#       'start': np.float64(41.68),
#       'end': np.float64(42.24),
#       'probability': np.float64(0.9989725351333618)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.21660717),
#     'female': np.float32(0.98693126),
#     'male': np.float32(0.0030739913),
#     'child': np.float32(0.009994695)}}),
#  ({'emotion2vec': {'angry': 0.00010549951548455283,
#     'disgusted': 0.0003499214071780443,
#     'fearful': 0.00018006931350100785,
#     'happy': 0.8496412038803101,
#     'neutral': 0.14839057624340057,
#     'other': 1.6532751033082604e-05,
#     'sad': 0.0010695277014747262,
#     'surprised': 0.00024651363492012024,
#     '<unk>': 9.435055403628212e-08},
#    'wav2vec2_emotion': {'arousal': np.float32(0.88228005),
#     'dominance': np.float32(0.7767215),
#     'valence': np.float32(0.50309235)},
#    'whisper': {'id': 8,
#     'seek': 2642,
#     'start': np.float64(44.52),
#     'end': np.float64(48.3),
#     'text': ' Александр, очень приятно. Скажите, Александр, есть ли условия все устроят?',
#     'tokens': [51270,
#      44938,
#      481,
#      11,
#      6730,
#      5082,
#      19005,
#      13,
#      22965,
#      3234,
#      5878,
#      11,
#      44938,
#      481,
#      11,
#      5640,
#      7444,
#      34974,
#      7409,
#      4640,
#      1595,
#      14086,
#      4558,
#      30,
#      51462],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Александр,',
#       'start': np.float64(44.52),
#       'end': np.float64(45.06),
#       'probability': np.float64(0.9932892918586731)},
#      {'word': ' очень',
#       'start': np.float64(45.06),
#       'end': np.float64(45.26),
#       'probability': np.float64(0.9976860284805298)},
#      {'word': ' приятно.',
#       'start': np.float64(45.26),
#       'end': np.float64(45.76),
#       'probability': np.float64(0.9999728202819824)},
#      {'word': ' Скажите,',
#       'start': np.float64(45.76),
#       'end': np.float64(46.1),
#       'probability': np.float64(0.9990557233492533)},
#      {'word': ' Александр,',
#       'start': np.float64(46.12),
#       'end': np.float64(46.58),
#       'probability': np.float64(0.9998891055583954)},
#      {'word': ' есть',
#       'start': np.float64(46.6),
#       'end': np.float64(46.88),
#       'probability': np.float64(0.5373654365539551)},
#      {'word': ' ли',
#       'start': np.float64(46.88),
#       'end': np.float64(47.04),
#       'probability': np.float64(0.9999699592590332)},
#      {'word': ' условия',
#       'start': np.float64(47.04),
#       'end': np.float64(47.6),
#       'probability': np.float64(0.9827556908130646)},
#      {'word': ' все',
#       'start': np.float64(47.6),
#       'end': np.float64(47.8),
#       'probability': np.float64(0.7138680815696716)},
#      {'word': ' устроят?',
#       'start': np.float64(47.8),
#       'end': np.float64(48.3),
#       'probability': np.float64(0.8993403116861979)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.2714468),
#     'female': np.float32(0.795327),
#     'male': np.float32(0.029800951),
#     'child': np.float32(0.174872)}}),
#  ({'emotion2vec': {'angry': 3.391184222323318e-09,
#     'disgusted': 1.5055322544199612e-09,
#     'fearful': 1.3293550704673862e-09,
#     'happy': 1.480776212758883e-08,
#     'neutral': 1.0,
#     'other': 2.0280201129541098e-11,
#     'sad': 4.051695157158974e-08,
#     'surprised': 1.185089248956217e-09,
#     '<unk>': 1.1287367525023018e-12},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7589708),
#     'dominance': np.float32(0.69053626),
#     'valence': np.float32(0.46223867)},
#    'whisper': {'id': 9,
#     'seek': 2642,
#     'start': np.float64(48.34),
#     'end': np.float64(51.14),
#     'text': ' Вы готовы рассмотреть покупку автомобиля в ближайшие 30 дней?',
#     'tokens': [51466,
#      11886,
#      17137,
#      698,
#      23345,
#      11128,
#      9108,
#      34005,
#      4401,
#      37122,
#      50211,
#      740,
#      21747,
#      1820,
#      3183,
#      35202,
#      2217,
#      47678,
#      30,
#      51605],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Вы',
#       'start': np.float64(48.34),
#       'end': np.float64(48.44),
#       'probability': np.float64(0.9985746145248413)},
#      {'word': ' готовы',
#       'start': np.float64(48.44),
#       'end': np.float64(48.76),
#       'probability': np.float64(0.9999038279056549)},
#      {'word': ' рассмотреть',
#       'start': np.float64(48.76),
#       'end': np.float64(49.12),
#       'probability': np.float64(0.9997291366259257)},
#      {'word': ' покупку',
#       'start': np.float64(49.12),
#       'end': np.float64(49.6),
#       'probability': np.float64(0.9999732971191406)},
#      {'word': ' автомобиля',
#       'start': np.float64(49.6),
#       'end': np.float64(50.06),
#       'probability': np.float64(0.9997313022613525)},
#      {'word': ' в',
#       'start': np.float64(50.06),
#       'end': np.float64(50.12),
#       'probability': np.float64(0.925521731376648)},
#      {'word': ' ближайшие',
#       'start': np.float64(50.12),
#       'end': np.float64(50.54),
#       'probability': np.float64(0.9999656081199646)},
#      {'word': ' 30',
#       'start': np.float64(50.54),
#       'end': np.float64(50.76),
#       'probability': np.float64(0.997850775718689)},
#      {'word': ' дней?',
#       'start': np.float64(50.76),
#       'end': np.float64(51.14),
#       'probability': np.float64(0.9999744892120361)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.18799049),
#     'female': np.float32(0.5143112),
#     'male': np.float32(0.03936615),
#     'child': np.float32(0.44632262)}}),
#  ({'emotion2vec': {'angry': 3.768857641262002e-05,
#     'disgusted': 6.984353240113705e-05,
#     'fearful': 3.3085707400459796e-05,
#     'happy': 0.0023997684475034475,
#     'neutral': 0.9965773224830627,
#     'other': 1.5438821492352872e-06,
#     'sad': 0.0007859376491978765,
#     'surprised': 9.476380364503711e-05,
#     '<unk>': 1.2951743144640204e-07},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7650615),
#     'dominance': np.float32(0.6776152),
#     'valence': np.float32(0.5637779)},
#    'whisper': {'id': 10,
#     'seek': 2642,
#     'start': np.float64(53.660000000000004),
#     'end': np.float64(56.4),
#     'text': ' А хорошо, тогда не кладите трубку, прямо сейчас соединяюсь.',
#     'tokens': [51605,
#      3450,
#      16977,
#      11,
#      21696,
#      1725,
#      981,
#      10396,
#      5878,
#      36310,
#      1552,
#      4401,
#      11,
#      28547,
#      10241,
#      7425,
#      30741,
#      681,
#      24551,
#      13,
#      51855],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' А',
#       'start': np.float64(53.660000000000004),
#       'end': np.float64(54.2),
#       'probability': np.float64(0.6692790985107422)},
#      {'word': ' хорошо,',
#       'start': np.float64(54.2),
#       'end': np.float64(54.42),
#       'probability': np.float64(0.965447723865509)},
#      {'word': ' тогда',
#       'start': np.float64(54.52),
#       'end': np.float64(54.7),
#       'probability': np.float64(0.999028205871582)},
#      {'word': ' не',
#       'start': np.float64(54.7),
#       'end': np.float64(54.92),
#       'probability': np.float64(0.9824097156524658)},
#      {'word': ' кладите',
#       'start': np.float64(54.92),
#       'end': np.float64(55.18),
#       'probability': np.float64(0.9863394300142924)},
#      {'word': ' трубку,',
#       'start': np.float64(55.18),
#       'end': np.float64(55.46),
#       'probability': np.float64(0.9982669353485107)},
#      {'word': ' прямо',
#       'start': np.float64(55.52),
#       'end': np.float64(55.68),
#       'probability': np.float64(0.991899847984314)},
#      {'word': ' сейчас',
#       'start': np.float64(55.68),
#       'end': np.float64(55.94),
#       'probability': np.float64(0.9999456405639648)},
#      {'word': ' соединяюсь.',
#       'start': np.float64(55.94),
#       'end': np.float64(56.4),
#       'probability': np.float64(0.8848365992307663)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.26883787),
#     'female': np.float32(0.63714886),
#     'male': np.float32(0.028298153),
#     'child': np.float32(0.33455303)}}),
#  ({'emotion2vec': {'angry': 3.2186413534418534e-09,
#     'disgusted': 6.8583259071886005e-09,
#     'fearful': 3.534675885319416e-09,
#     'happy': 4.983601087360512e-08,
#     'neutral': 0.9999918937683105,
#     'other': 5.919224832506842e-11,
#     'sad': 8.150979738275055e-06,
#     'surprised': 1.2285867878603085e-09,
#     '<unk>': 1.1940524354589043e-14},
#    'wav2vec2_emotion': {'arousal': np.float32(0.509103),
#     'dominance': np.float32(0.4512255),
#     'valence': np.float32(0.48999804)},
#    'whisper': {'id': 11,
#     'seek': 5642,
#     'start': np.float64(56.42),
#     'end': np.float64(56.78),
#     'text': ' Спасибо, менеджер.',
#     'tokens': [50365, 29219, 11, 6046, 2229, 1820, 1135, 13, 50386],
#     'temperature': 0.0,
#     'avg_logprob': -0.5619863033294678,
#     'compression_ratio': 0.7857142857142857,
#     'no_speech_prob': 0.12912438809871674,
#     'words': [{'word': ' Спасибо,',
#       'start': np.float64(56.42),
#       'end': np.float64(56.6),
#       'probability': np.float64(0.0013981651281937957)},
#      {'word': ' менеджер.',
#       'start': np.float64(56.6),
#       'end': np.float64(56.78),
#       'probability': np.float64(0.7188988163834438)}]}},
#   {'wav2vec2_age_gender': {'age': np.float32(0.24368806),
#     'female': np.float32(0.9671252),
#     'male': np.float32(0.019580483),
#     'child': np.float32(0.013294325)}})]

# %%
import numpy as np

phrase_metrics, recording_metrics = zip(*raw_metrics)

metrics = dict(
    recording = dict(),
    phrase = list(phrase_metrics)
)

for name in PER_RECORDING_METRIC_NAMES:
    mean = np.mean([list(metrics[name].values()) for metrics in recording_metrics], axis=0)
    metrics["recording"][name] = {k: v for (k, v) in zip(recording_metrics[0][name].keys(), mean)}

metrics
# Out:
# {'recording': {'wav2vec2_age_gender': {'age': np.float32(0.2541189),
#    'female': np.float32(0.73997617),
#    'male': np.float32(0.02599925),
#    'child': np.float32(0.23402464)}},
#  'phrase': [{'emotion2vec': {'angry': 3.7985137169016525e-05,
#     'disgusted': 0.00010294616367900744,
#     'fearful': 0.0001235693198395893,
#     'happy': 0.002397349802777171,
#     'neutral': 0.9833465814590454,
#     'other': 8.582897862652317e-05,
#     'sad': 0.0006209969869814813,
#     'surprised': 1.0889703844441101e-05,
#     '<unk>': 0.013273905962705612},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7356798),
#     'dominance': np.float32(0.6685522),
#     'valence': np.float32(0.3694641)},
#    'whisper': {'id': 0,
#     'seek': 0,
#     'start': np.float64(0.0),
#     'end': np.float64(6.34),
#     'text': ' Добрый день, меня зовут Вадим, я представляю Автомир, официального дилера ХВЛ.',
#     'tokens': [50365,
#      3401,
#      13829,
#      4851,
#      13509,
#      11,
#      6885,
#      46376,
#      2348,
#      2601,
#      2165,
#      11,
#      2552,
#      39412,
#      1148,
#      50175,
#      17804,
#      4490,
#      11,
#      31950,
#      30321,
#      31227,
#      1070,
#      2338,
#      13126,
#      9456,
#      8578,
#      14854,
#      13,
#      50691],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' Добрый',
#       'start': np.float64(0.0),
#       'end': np.float64(1.24),
#       'probability': np.float64(0.7450953722000122)},
#      {'word': ' день,',
#       'start': np.float64(1.24),
#       'end': np.float64(1.36),
#       'probability': np.float64(0.9973821043968201)},
#      {'word': ' меня',
#       'start': np.float64(1.46),
#       'end': np.float64(2.74),
#       'probability': np.float64(0.8405876755714417)},
#      {'word': ' зовут',
#       'start': np.float64(2.74),
#       'end': np.float64(3.04),
#       'probability': np.float64(0.9977419376373291)},
#      {'word': ' Вадим,',
#       'start': np.float64(3.04),
#       'end': np.float64(3.46),
#       'probability': np.float64(0.9954708019892374)},
#      {'word': ' я',
#       'start': np.float64(3.46),
#       'end': np.float64(3.8),
#       'probability': np.float64(0.9797195792198181)},
#      {'word': ' представляю',
#       'start': np.float64(3.8),
#       'end': np.float64(4.4),
#       'probability': np.float64(0.9754282236099243)},
#      {'word': ' Автомир,',
#       'start': np.float64(4.4),
#       'end': np.float64(4.96),
#       'probability': np.float64(0.8010528087615967)},
#      {'word': ' официального',
#       'start': np.float64(5.0),
#       'end': np.float64(5.46),
#       'probability': np.float64(0.869212826093038)},
#      {'word': ' дилера',
#       'start': np.float64(5.46),
#       'end': np.float64(5.94),
#       'probability': np.float64(0.9953171412150065)},
#      {'word': ' ХВЛ.',
#       'start': np.float64(5.94),
#       'end': np.float64(6.34),
#       'probability': np.float64(0.5703746279080709)}]}},
#   {'emotion2vec': {'angry': 3.191628081822273e-07,
#     'disgusted': 5.845498662893078e-07,
#     'fearful': 7.850135261833202e-07,
#     'happy': 1.3677405149792321e-05,
#     'neutral': 0.9999760389328003,
#     'other': 3.079767623148655e-07,
#     'sad': 4.081447968928842e-06,
#     'surprised': 4.472383707820882e-08,
#     '<unk>': 4.036787686345633e-06},
#    'wav2vec2_emotion': {'arousal': np.float32(0.6963425),
#     'dominance': np.float32(0.6634601),
#     'valence': np.float32(0.48574674)},
#    'whisper': {'id': 1,
#     'seek': 0,
#     'start': np.float64(6.54),
#     'end': np.float64(10.16),
#     'text': ' Вы планируете покупку нового автомобиля ХВЛ в Самаре в ближайший месяц?',
#     'tokens': [50705,
#      11886,
#      9283,
#      3733,
#      2711,
#      10524,
#      34005,
#      4401,
#      10022,
#      2350,
#      37122,
#      50211,
#      9456,
#      8578,
#      14854,
#      740,
#      31152,
#      2222,
#      387,
#      740,
#      21747,
#      1820,
#      3183,
#      24958,
#      29329,
#      1814,
#      30,
#      50882],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' Вы',
#       'start': np.float64(6.54),
#       'end': np.float64(6.84),
#       'probability': np.float64(0.9991627931594849)},
#      {'word': ' планируете',
#       'start': np.float64(6.84),
#       'end': np.float64(7.32),
#       'probability': np.float64(0.9998561590909958)},
#      {'word': ' покупку',
#       'start': np.float64(7.32),
#       'end': np.float64(7.8),
#       'probability': np.float64(0.9995855093002319)},
#      {'word': ' нового',
#       'start': np.float64(7.8),
#       'end': np.float64(8.02),
#       'probability': np.float64(0.9989623725414276)},
#      {'word': ' автомобиля',
#       'start': np.float64(8.02),
#       'end': np.float64(8.44),
#       'probability': np.float64(0.9783834517002106)},
#      {'word': ' ХВЛ',
#       'start': np.float64(8.44),
#       'end': np.float64(8.82),
#       'probability': np.float64(0.9985711574554443)},
#      {'word': ' в',
#       'start': np.float64(8.82),
#       'end': np.float64(9.02),
#       'probability': np.float64(0.9996521472930908)},
#      {'word': ' Самаре',
#       'start': np.float64(9.02),
#       'end': np.float64(9.36),
#       'probability': np.float64(0.9987807869911194)},
#      {'word': ' в',
#       'start': np.float64(9.36),
#       'end': np.float64(9.42),
#       'probability': np.float64(0.9927818775177002)},
#      {'word': ' ближайший',
#       'start': np.float64(9.42),
#       'end': np.float64(9.74),
#       'probability': np.float64(0.9056216776371002)},
#      {'word': ' месяц?',
#       'start': np.float64(9.74),
#       'end': np.float64(10.16),
#       'probability': np.float64(0.9997113347053528)}]}},
#   {'emotion2vec': {'angry': 1.4713505152030848e-05,
#     'disgusted': 2.929203947132919e-05,
#     'fearful': 3.29303766193334e-05,
#     'happy': 0.00225819437764585,
#     'neutral': 0.9960667490959167,
#     'other': 7.336878837804761e-08,
#     'sad': 0.0011225345078855753,
#     'surprised': 0.000475504610221833,
#     '<unk>': 4.698206712561159e-09},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7288242),
#     'dominance': np.float32(0.6378156),
#     'valence': np.float32(0.601018)},
#    'whisper': {'id': 2,
#     'seek': 0,
#     'start': np.float64(15.08),
#     'end': np.float64(17.28),
#     'text': ' Скажите, какая модель вас интересует?',
#     'tokens': [51123,
#      22965,
#      3234,
#      5878,
#      11,
#      29334,
#      24104,
#      3908,
#      10655,
#      15033,
#      17781,
#      30,
#      51236],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' Скажите,',
#       'start': np.float64(15.08),
#       'end': np.float64(15.88),
#       'probability': np.float64(0.9521047671635946)},
#      {'word': ' какая',
#       'start': np.float64(15.88),
#       'end': np.float64(16.08),
#       'probability': np.float64(0.9999152421951294)},
#      {'word': ' модель',
#       'start': np.float64(16.08),
#       'end': np.float64(16.48),
#       'probability': np.float64(0.9999237656593323)},
#      {'word': ' вас',
#       'start': np.float64(16.48),
#       'end': np.float64(16.62),
#       'probability': np.float64(0.8566867113113403)},
#      {'word': ' интересует?',
#       'start': np.float64(16.62),
#       'end': np.float64(17.28),
#       'probability': np.float64(0.9999722838401794)}]}},
#   {'emotion2vec': {'angry': 0.00016556431364733726,
#     'disgusted': 0.0010418196907266974,
#     'fearful': 0.00031519183539785445,
#     'happy': 0.02753724530339241,
#     'neutral': 0.9685339331626892,
#     'other': 0.00010792788089020178,
#     'sad': 0.0009069611551240087,
#     'surprised': 0.0002124914899468422,
#     '<unk>': 0.0011789770796895027},
#    'wav2vec2_emotion': {'arousal': np.float32(0.6523959),
#     'dominance': np.float32(0.56699634),
#     'valence': np.float32(0.4112126)},
#    'whisper': {'id': 3,
#     'seek': 0,
#     'start': np.float64(22.06),
#     'end': np.float64(23.68),
#     'text': ' F7 или H7?',
#     'tokens': [51474, 479, 22, 8101, 389, 22, 30, 51558],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' F7',
#       'start': np.float64(22.06),
#       'end': np.float64(22.86),
#       'probability': np.float64(0.9442199170589447)},
#      {'word': ' или',
#       'start': np.float64(22.86),
#       'end': np.float64(23.04),
#       'probability': np.float64(0.9793375730514526)},
#      {'word': ' H7?',
#       'start': np.float64(23.04),
#       'end': np.float64(23.68),
#       'probability': np.float64(0.9993142187595367)}]}},
#   {'emotion2vec': {'angry': 0.00011868292494909838,
#     'disgusted': 0.00017413331079296768,
#     'fearful': 0.0001662678987486288,
#     'happy': 0.8755322098731995,
#     'neutral': 0.014197878539562225,
#     'other': 2.12881037242596e-08,
#     'sad': 0.0006305084680207074,
#     'surprised': 0.10918023437261581,
#     '<unk>': 1.0591821819616598e-07},
#    'wav2vec2_emotion': {'arousal': np.float32(0.6402663),
#     'dominance': np.float32(0.56835485),
#     'valence': np.float32(0.33883637)},
#    'whisper': {'id': 4,
#     'seek': 0,
#     'start': np.float64(25.62),
#     'end': np.float64(26.42),
#     'text': ' F7?',
#     'tokens': [51655, 479, 22, 30, 51695],
#     'temperature': 0.0,
#     'avg_logprob': -0.2778836405554483,
#     'compression_ratio': 1.5833333333333333,
#     'no_speech_prob': 0.25860750675201416,
#     'words': [{'word': ' F7?',
#       'start': np.float64(25.62),
#       'end': np.float64(26.42),
#       'probability': np.float64(0.985101044178009)}]}},
#   {'emotion2vec': {'angry': 0.0005239499150775373,
#     'disgusted': 0.0011846543056890368,
#     'fearful': 0.0018442034488543868,
#     'happy': 0.7580862641334534,
#     'neutral': 0.18431128561496735,
#     'other': 0.004760020412504673,
#     'sad': 0.010309253819286823,
#     'surprised': 0.00013269041664898396,
#     '<unk>': 0.038847655057907104},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7595975),
#     'dominance': np.float32(0.6692323),
#     'valence': np.float32(0.5013543)},
#    'whisper': {'id': 5,
#     'seek': 2642,
#     'start': np.float64(28.860000000000003),
#     'end': np.float64(32.04),
#     'text': ' А покупку планируете как физическое или как юридическое лицо?',
#     'tokens': [50365,
#      3450,
#      34005,
#      4401,
#      9283,
#      3733,
#      2711,
#      10524,
#      3014,
#      44662,
#      9347,
#      22128,
#      8101,
#      3014,
#      29488,
#      481,
#      3586,
#      9347,
#      22128,
#      7444,
#      44569,
#      30,
#      50654],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' А',
#       'start': np.float64(28.860000000000003),
#       'end': np.float64(29.400000000000002),
#       'probability': np.float64(0.12866728007793427)},
#      {'word': ' покупку',
#       'start': np.float64(29.400000000000002),
#       'end': np.float64(29.94),
#       'probability': np.float64(0.8625057935714722)},
#      {'word': ' планируете',
#       'start': np.float64(29.94),
#       'end': np.float64(30.38),
#       'probability': np.float64(0.9567026495933533)},
#      {'word': ' как',
#       'start': np.float64(30.38),
#       'end': np.float64(30.54),
#       'probability': np.float64(0.9871406555175781)},
#      {'word': ' физическое',
#       'start': np.float64(30.54),
#       'end': np.float64(31.04),
#       'probability': np.float64(0.9959108233451843)},
#      {'word': ' или',
#       'start': np.float64(31.04),
#       'end': np.float64(31.14),
#       'probability': np.float64(0.9524978995323181)},
#      {'word': ' как',
#       'start': np.float64(31.14),
#       'end': np.float64(31.28),
#       'probability': np.float64(0.9640295505523682)},
#      {'word': ' юридическое',
#       'start': np.float64(31.28),
#       'end': np.float64(31.86),
#       'probability': np.float64(0.9990940690040588)},
#      {'word': ' лицо?',
#       'start': np.float64(31.86),
#       'end': np.float64(32.04),
#       'probability': np.float64(0.9456607103347778)}]}},
#   {'emotion2vec': {'angry': 2.3686850909143686e-05,
#     'disgusted': 6.189792475197464e-05,
#     'fearful': 5.8695051848189905e-05,
#     'happy': 0.009599989280104637,
#     'neutral': 0.9895317554473877,
#     'other': 9.025319013744593e-05,
#     'sad': 0.00035178798134438694,
#     'surprised': 4.672315753850853e-06,
#     '<unk>': 0.0002772207953967154},
#    'wav2vec2_emotion': {'arousal': np.float32(0.8439917),
#     'dominance': np.float32(0.75498277),
#     'valence': np.float32(0.42179906)},
#    'whisper': {'id': 6,
#     'seek': 2642,
#     'start': np.float64(36.06),
#     'end': np.float64(40.88),
#     'text': ' Тогда давайте я прямо сейчас соединю вас с менеджером, который подберет предложение по вашим параметрам.',
#     'tokens': [50857,
#      46357,
#      30412,
#      2552,
#      28547,
#      10241,
#      7425,
#      30741,
#      1148,
#      10655,
#      776,
#      6046,
#      2229,
#      1820,
#      33370,
#      11,
#      11897,
#      4095,
#      1552,
#      1135,
#      1094,
#      40373,
#      5627,
#      2801,
#      14536,
#      2165,
#      11813,
#      1685,
#      1094,
#      15837,
#      13,
#      51094],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Тогда',
#       'start': np.float64(36.06),
#       'end': np.float64(36.6),
#       'probability': np.float64(0.5114366412162781)},
#      {'word': ' давайте',
#       'start': np.float64(36.6),
#       'end': np.float64(37.06),
#       'probability': np.float64(0.9902661442756653)},
#      {'word': ' я',
#       'start': np.float64(37.06),
#       'end': np.float64(37.26),
#       'probability': np.float64(0.9984096884727478)},
#      {'word': ' прямо',
#       'start': np.float64(37.26),
#       'end': np.float64(37.38),
#       'probability': np.float64(0.9473075270652771)},
#      {'word': ' сейчас',
#       'start': np.float64(37.38),
#       'end': np.float64(37.62),
#       'probability': np.float64(0.9997419714927673)},
#      {'word': ' соединю',
#       'start': np.float64(37.62),
#       'end': np.float64(38.02),
#       'probability': np.float64(0.9596470395723978)},
#      {'word': ' вас',
#       'start': np.float64(38.02),
#       'end': np.float64(38.24),
#       'probability': np.float64(0.9489714503288269)},
#      {'word': ' с',
#       'start': np.float64(38.24),
#       'end': np.float64(38.36),
#       'probability': np.float64(0.998415470123291)},
#      {'word': ' менеджером,',
#       'start': np.float64(38.36),
#       'end': np.float64(38.7),
#       'probability': np.float64(0.99949149787426)},
#      {'word': ' который',
#       'start': np.float64(38.72),
#       'end': np.float64(38.92),
#       'probability': np.float64(0.9991275668144226)},
#      {'word': ' подберет',
#       'start': np.float64(38.92),
#       'end': np.float64(39.34),
#       'probability': np.float64(0.9982127547264099)},
#      {'word': ' предложение',
#       'start': np.float64(39.34),
#       'end': np.float64(39.92),
#       'probability': np.float64(0.9946097731590271)},
#      {'word': ' по',
#       'start': np.float64(39.92),
#       'end': np.float64(40.08),
#       'probability': np.float64(0.999721109867096)},
#      {'word': ' вашим',
#       'start': np.float64(40.08),
#       'end': np.float64(40.44),
#       'probability': np.float64(0.9982703328132629)},
#      {'word': ' параметрам.',
#       'start': np.float64(40.44),
#       'end': np.float64(40.88),
#       'probability': np.float64(0.999767616391182)}]}},
#   {'emotion2vec': {'angry': 7.897557225078344e-05,
#     'disgusted': 0.00010565540287643671,
#     'fearful': 9.837070683715865e-05,
#     'happy': 0.0005510866176337004,
#     'neutral': 0.9970014691352844,
#     'other': 5.352133598535147e-07,
#     'sad': 0.0014683923218399286,
#     'surprised': 0.0006943087209947407,
#     '<unk>': 1.2786388197127962e-06},
#    'wav2vec2_emotion': {'arousal': np.float32(0.682087),
#     'dominance': np.float32(0.60564756),
#     'valence': np.float32(0.46296152)},
#    'whisper': {'id': 7,
#     'seek': 2642,
#     'start': np.float64(41.0),
#     'end': np.float64(42.24),
#     'text': ' Как могу вас представить?',
#     'tokens': [51105, 11011, 22951, 10655, 27167, 3258, 30, 51162],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Как',
#       'start': np.float64(41.0),
#       'end': np.float64(41.26),
#       'probability': np.float64(0.9964990615844727)},
#      {'word': ' могу',
#       'start': np.float64(41.26),
#       'end': np.float64(41.5),
#       'probability': np.float64(0.997516393661499)},
#      {'word': ' вас',
#       'start': np.float64(41.5),
#       'end': np.float64(41.68),
#       'probability': np.float64(0.9966896772384644)},
#      {'word': ' представить?',
#       'start': np.float64(41.68),
#       'end': np.float64(42.24),
#       'probability': np.float64(0.9989725351333618)}]}},
#   {'emotion2vec': {'angry': 0.00010549951548455283,
#     'disgusted': 0.0003499214071780443,
#     'fearful': 0.00018006931350100785,
#     'happy': 0.8496412038803101,
#     'neutral': 0.14839057624340057,
#     'other': 1.6532751033082604e-05,
#     'sad': 0.0010695277014747262,
#     'surprised': 0.00024651363492012024,
#     '<unk>': 9.435055403628212e-08},
#    'wav2vec2_emotion': {'arousal': np.float32(0.88228005),
#     'dominance': np.float32(0.7767215),
#     'valence': np.float32(0.50309235)},
#    'whisper': {'id': 8,
#     'seek': 2642,
#     'start': np.float64(44.52),
#     'end': np.float64(48.3),
#     'text': ' Александр, очень приятно. Скажите, Александр, есть ли условия все устроят?',
#     'tokens': [51270,
#      44938,
#      481,
#      11,
#      6730,
#      5082,
#      19005,
#      13,
#      22965,
#      3234,
#      5878,
#      11,
#      44938,
#      481,
#      11,
#      5640,
#      7444,
#      34974,
#      7409,
#      4640,
#      1595,
#      14086,
#      4558,
#      30,
#      51462],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Александр,',
#       'start': np.float64(44.52),
#       'end': np.float64(45.06),
#       'probability': np.float64(0.9932892918586731)},
#      {'word': ' очень',
#       'start': np.float64(45.06),
#       'end': np.float64(45.26),
#       'probability': np.float64(0.9976860284805298)},
#      {'word': ' приятно.',
#       'start': np.float64(45.26),
#       'end': np.float64(45.76),
#       'probability': np.float64(0.9999728202819824)},
#      {'word': ' Скажите,',
#       'start': np.float64(45.76),
#       'end': np.float64(46.1),
#       'probability': np.float64(0.9990557233492533)},
#      {'word': ' Александр,',
#       'start': np.float64(46.12),
#       'end': np.float64(46.58),
#       'probability': np.float64(0.9998891055583954)},
#      {'word': ' есть',
#       'start': np.float64(46.6),
#       'end': np.float64(46.88),
#       'probability': np.float64(0.5373654365539551)},
#      {'word': ' ли',
#       'start': np.float64(46.88),
#       'end': np.float64(47.04),
#       'probability': np.float64(0.9999699592590332)},
#      {'word': ' условия',
#       'start': np.float64(47.04),
#       'end': np.float64(47.6),
#       'probability': np.float64(0.9827556908130646)},
#      {'word': ' все',
#       'start': np.float64(47.6),
#       'end': np.float64(47.8),
#       'probability': np.float64(0.7138680815696716)},
#      {'word': ' устроят?',
#       'start': np.float64(47.8),
#       'end': np.float64(48.3),
#       'probability': np.float64(0.8993403116861979)}]}},
#   {'emotion2vec': {'angry': 3.391184222323318e-09,
#     'disgusted': 1.5055322544199612e-09,
#     'fearful': 1.3293550704673862e-09,
#     'happy': 1.480776212758883e-08,
#     'neutral': 1.0,
#     'other': 2.0280201129541098e-11,
#     'sad': 4.051695157158974e-08,
#     'surprised': 1.185089248956217e-09,
#     '<unk>': 1.1287367525023018e-12},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7589708),
#     'dominance': np.float32(0.69053626),
#     'valence': np.float32(0.46223867)},
#    'whisper': {'id': 9,
#     'seek': 2642,
#     'start': np.float64(48.34),
#     'end': np.float64(51.14),
#     'text': ' Вы готовы рассмотреть покупку автомобиля в ближайшие 30 дней?',
#     'tokens': [51466,
#      11886,
#      17137,
#      698,
#      23345,
#      11128,
#      9108,
#      34005,
#      4401,
#      37122,
#      50211,
#      740,
#      21747,
#      1820,
#      3183,
#      35202,
#      2217,
#      47678,
#      30,
#      51605],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' Вы',
#       'start': np.float64(48.34),
#       'end': np.float64(48.44),
#       'probability': np.float64(0.9985746145248413)},
#      {'word': ' готовы',
#       'start': np.float64(48.44),
#       'end': np.float64(48.76),
#       'probability': np.float64(0.9999038279056549)},
#      {'word': ' рассмотреть',
#       'start': np.float64(48.76),
#       'end': np.float64(49.12),
#       'probability': np.float64(0.9997291366259257)},
#      {'word': ' покупку',
#       'start': np.float64(49.12),
#       'end': np.float64(49.6),
#       'probability': np.float64(0.9999732971191406)},
#      {'word': ' автомобиля',
#       'start': np.float64(49.6),
#       'end': np.float64(50.06),
#       'probability': np.float64(0.9997313022613525)},
#      {'word': ' в',
#       'start': np.float64(50.06),
#       'end': np.float64(50.12),
#       'probability': np.float64(0.925521731376648)},
#      {'word': ' ближайшие',
#       'start': np.float64(50.12),
#       'end': np.float64(50.54),
#       'probability': np.float64(0.9999656081199646)},
#      {'word': ' 30',
#       'start': np.float64(50.54),
#       'end': np.float64(50.76),
#       'probability': np.float64(0.997850775718689)},
#      {'word': ' дней?',
#       'start': np.float64(50.76),
#       'end': np.float64(51.14),
#       'probability': np.float64(0.9999744892120361)}]}},
#   {'emotion2vec': {'angry': 3.768857641262002e-05,
#     'disgusted': 6.984353240113705e-05,
#     'fearful': 3.3085707400459796e-05,
#     'happy': 0.0023997684475034475,
#     'neutral': 0.9965773224830627,
#     'other': 1.5438821492352872e-06,
#     'sad': 0.0007859376491978765,
#     'surprised': 9.476380364503711e-05,
#     '<unk>': 1.2951743144640204e-07},
#    'wav2vec2_emotion': {'arousal': np.float32(0.7650615),
#     'dominance': np.float32(0.6776152),
#     'valence': np.float32(0.5637779)},
#    'whisper': {'id': 10,
#     'seek': 2642,
#     'start': np.float64(53.660000000000004),
#     'end': np.float64(56.4),
#     'text': ' А хорошо, тогда не кладите трубку, прямо сейчас соединяюсь.',
#     'tokens': [51605,
#      3450,
#      16977,
#      11,
#      21696,
#      1725,
#      981,
#      10396,
#      5878,
#      36310,
#      1552,
#      4401,
#      11,
#      28547,
#      10241,
#      7425,
#      30741,
#      681,
#      24551,
#      13,
#      51855],
#     'temperature': 0.0,
#     'avg_logprob': -0.1246257048386794,
#     'compression_ratio': 2.0113636363636362,
#     'no_speech_prob': 0.016652150079607964,
#     'words': [{'word': ' А',
#       'start': np.float64(53.660000000000004),
#       'end': np.float64(54.2),
#       'probability': np.float64(0.6692790985107422)},
#      {'word': ' хорошо,',
#       'start': np.float64(54.2),
#       'end': np.float64(54.42),
#       'probability': np.float64(0.965447723865509)},
#      {'word': ' тогда',
#       'start': np.float64(54.52),
#       'end': np.float64(54.7),
#       'probability': np.float64(0.999028205871582)},
#      {'word': ' не',
#       'start': np.float64(54.7),
#       'end': np.float64(54.92),
#       'probability': np.float64(0.9824097156524658)},
#      {'word': ' кладите',
#       'start': np.float64(54.92),
#       'end': np.float64(55.18),
#       'probability': np.float64(0.9863394300142924)},
#      {'word': ' трубку,',
#       'start': np.float64(55.18),
#       'end': np.float64(55.46),
#       'probability': np.float64(0.9982669353485107)},
#      {'word': ' прямо',
#       'start': np.float64(55.52),
#       'end': np.float64(55.68),
#       'probability': np.float64(0.991899847984314)},
#      {'word': ' сейчас',
#       'start': np.float64(55.68),
#       'end': np.float64(55.94),
#       'probability': np.float64(0.9999456405639648)},
#      {'word': ' соединяюсь.',
#       'start': np.float64(55.94),
#       'end': np.float64(56.4),
#       'probability': np.float64(0.8848365992307663)}]}},
#   {'emotion2vec': {'angry': 3.2186413534418534e-09,
#     'disgusted': 6.8583259071886005e-09,
#     'fearful': 3.534675885319416e-09,
#     'happy': 4.983601087360512e-08,
#     'neutral': 0.9999918937683105,
#     'other': 5.919224832506842e-11,
#     'sad': 8.150979738275055e-06,
#     'surprised': 1.2285867878603085e-09,
#     '<unk>': 1.1940524354589043e-14},
#    'wav2vec2_emotion': {'arousal': np.float32(0.509103),
#     'dominance': np.float32(0.4512255),
#     'valence': np.float32(0.48999804)},
#    'whisper': {'id': 11,
#     'seek': 5642,
#     'start': np.float64(56.42),
#     'end': np.float64(56.78),
#     'text': ' Спасибо, менеджер.',
#     'tokens': [50365, 29219, 11, 6046, 2229, 1820, 1135, 13, 50386],
#     'temperature': 0.0,
#     'avg_logprob': -0.5619863033294678,
#     'compression_ratio': 0.7857142857142857,
#     'no_speech_prob': 0.12912438809871674,
#     'words': [{'word': ' Спасибо,',
#       'start': np.float64(56.42),
#       'end': np.float64(56.6),
#       'probability': np.float64(0.0013981651281937957)},
#      {'word': ' менеджер.',
#       'start': np.float64(56.6),
#       'end': np.float64(56.78),
#       'probability': np.float64(0.7188988163834438)}]}}]}

# %%
import json

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

json_str = json.dumps(metrics, indent=4, cls=NpEncoder)
with open(SPEAKER1_METRICS_FILE, "w") as f:
    f.write(json_str)
